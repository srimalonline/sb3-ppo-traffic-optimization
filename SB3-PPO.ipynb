# %%
# !pip install stable-baselines3
# Out:
# Collecting stable-baselines3
#   Using cached stable_baselines3-2.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from stable-baselines3) (0.29.1)
# Requirement already satisfied: numpy<3.0,>=1.20 in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3) (1.26.4)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from stable-baselines3) (2.4.0)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3) (3.8.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\programdata\anaconda3\lib\site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.13.1)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.12)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.4)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (2024.3.1)
# Requirement already satisfied: setuptools in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torch<3.0,>=2.3->stable-baselines3) (72.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (23.2)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas->stable-baselines3) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Using cached stable_baselines3-2.5.0-py3-none-any.whl (183 kB)
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.5.0

# %%
# !pip3 install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in c:\programdata\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: torchvision in c:\programdata\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: torchaudio in c:\programdata\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\programdata\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: setuptools in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torch) (72.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\programdata\anaconda3\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)

# %%
import numpy as np
import random
from gymnasium import Env
from gymnasium.spaces import Box, MultiDiscrete
from stable_baselines3 import PPO
import os
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 5
#       3 from gymnasium import Env
#       4 from gymnasium.spaces import Box, MultiDiscrete
# ----> 5 from stable_baselines3 import PPO
#       6 import os
#
# File C:\ProgramData\anaconda3\Lib\site-packages\stable_baselines3\__init__.py:3
#       1 import os
# ----> 3 from stable_baselines3.a2c import A2C
#       4 from stable_baselines3.common.utils import get_system_info
#       5 from stable_baselines3.ddpg import DDPG
#
# File C:\ProgramData\anaconda3\Lib\site-packages\stable_baselines3\a2c\__init__.py:1
# ----> 1 from stable_baselines3.a2c.a2c import A2C
#       2 from stable_baselines3.a2c.policies import CnnPolicy, MlpPolicy, MultiInputPolicy
#       4 __all__ = ["A2C", "CnnPolicy", "MlpPolicy", "MultiInputPolicy"]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\stable_baselines3\a2c\a2c.py:3
#       1 from typing import Any, ClassVar, Optional, TypeVar, Union
# ----> 3 import torch as th
#       4 from gymnasium import spaces
#       5 from torch.nn import functional as F
#
# File C:\ProgramData\anaconda3\Lib\site-packages\torch\__init__.py:274
#     270                     raise err
#     272         kernel32.SetErrorMode(prev_error_mode)
# --> 274     _load_dll_libraries()
#     275     del _load_dll_libraries
#     278 def _preload_cuda_deps(lib_folder: str, lib_name: str) -> None:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\torch\__init__.py:257, in _load_dll_libraries()
#     253     err = ctypes.WinError(last_error)
#     254     err.strerror += (
#     255         f' Error loading "{dll}" or one of its dependencies.'
#     256     )
# --> 257     raise err
#     258 elif res is not None:
#     259     is_loaded = True
#
# OSError: [WinError 127] The specified procedure could not be found. Error loading "C:\ProgramData\anaconda3\Lib\site-packages\torch\lib\shm.dll" or one of its dependencies.

# %%
class TrafficSimulation(Env):
    def __init__(self):
        super(TrafficSimulation, self).__init__()

        # Define the observation space as a Box space with densities
        self.observation_space = Box(low=0, high=np.inf, shape=(8,), dtype=np.float32)

        # Define the action space as a MultiDiscrete
        self.action_space = MultiDiscrete([
            7,  # com: 7 possible combinations (0 to 6, mapped to 1-7)
            36, 36, 36, 36  # side-timers: 4 values each ranging from 5 to 40 (5 + i where i is in range(0, 36))  min_density = max(np.min(observation), 0.1) 
        ])
        # Episode length and state initialization
        self.episode_length = 15
        self.current_step = 0

        import pynetlogo
        
        self.netlogo = pynetlogo.NetLogoLink(
            jvm_path=r"C:\Program Files\Java\jdk-19\bin\server\jvm.dll",
            gui=True,
            #netlogo_home=r'/home/srimal/Downloads/NetLogo-6.4.0-64'
            
        )

        self.netlogo.load_model(r'4Way-Junction-Traffic-Simulation-SriLanka.nlogo')
        self.netlogo.command('setup')  # Initialize NetLogo simulation

        # Initialize previous density standard deviation for reward calculation
        self.previous_density_stdev = 0  # Initial state with no densities

    def reset(self, seed=None, options=None):
        """
        Reset the environment state.
        """
        super().reset(seed=seed)  # Properly handle seeding
        
        # Initialize episode length and current step
        self.current_step = 0

        # Reset NetLogo simulation
        self.netlogo.command('setup')

        # Initialize observation with default densities as zeros since no initial densities
        observation = np.zeros(8, dtype=np.float32)  # All densities start at zero
        
        # Reset previous density standard deviation
        self.previous_density_stdev = 0

        return observation, {}

    def step(self, action):
        """
        Perform one step in the environment.
        """
        # Decode the action
        selected_combination = int(action[0]) + 1  # Value for 'com' (1 to 7)
        green_light_durations = [int(g + 5) for g in action[1:]]  # Values for 'side-timers' adjusted back to 5-40 range
    
        # Update NetLogo with the selected combination and timers
        self.netlogo.command(f'set routes-combinations "com{selected_combination}"')
        self.netlogo.command(f'set side1 {green_light_durations[0]}')
        self.netlogo.command(f'set side2 {green_light_durations[1]}')
        self.netlogo.command(f'set side3 {green_light_durations[2]}')
        self.netlogo.command(f'set side4 {green_light_durations[3]}')
    
        # Run the NetLogo model until the cycle completes
        self.netlogo.command('go-cycle')  # Use the go-cycle method to run a full cycle
    
        # Get the new observation (densities)
        observation = self.get_current_densities()
    
        # Check if all observations are 0 (potential deadlock)
        if np.all(observation == 0):
            print("Deadlock detected: All densities are 0. Ending episode early.")
            reward = -10  # Provide a significant negative reward for deadlock
            done = True  # End the episode
            truncated = True  # Indicate that it was truncated
            info = {"reason": "deadlock"}  # Provide additional info about the deadlock
            return observation, reward, done, truncated, info

        # Calculate the minimum density and set it as min-density in NetLogo
        min_density = max(np.min(observation), 0.8) 
        print(f"Setting min-density to {min_density}")
        self.netlogo.command(f'set min-density {min_density}')  # Update the min-density in NetLogo
    
        # Calculate reward
        new_density_stdev = np.std(observation)
        reward = 0
        if new_density_stdev < self.previous_density_stdev:
            reward = 1
        elif new_density_stdev > self.previous_density_stdev:
            reward = -1
    
        # Update the previous density standard deviation
        self.previous_density_stdev = new_density_stdev
    
        # Check if the episode is done
        self.current_step += 1
        done = self.current_step >= self.episode_length
    
        # No truncation in this simple example
        truncated = False
        info = {}
    
        return observation, reward, done, truncated, info


    def get_current_densities(self):
        """
        Get the current traffic densities from NetLogo using the `check_density()` function.
        """
        densities_dict = self.check_density()
        densities = np.array(list(densities_dict.values()))
        return densities

    def check_density(self):
        """
        Calculate and return traffic densities based on the current route combination.
        """
        current_com = self.netlogo.report('routes-combinations')

        # Define the routes combination dictionary
        routes_combination = {
            "com1": ['R12', 'R34', 'R56', 'R78', None],
            "com2": ['R12', 'R37', 'R48', 'R56', None],
            "com3": ['R14', 'R26', 'R37', 'R58', None],
            "com4": ['R14', 'R27', 'R36', 'R58', None],
            "com5": ['R15', 'R26', 'R34', 'R78', None],
            "com6": ['R15', 'R26', 'R37', 'R48', None],
            "com7": ['R15', 'R27', 'R36', 'R48', None]
        }
        
        # Define the routes dictionary
        routes = {
            'R12': ['S1', 'S2', None],
            'R14': ['S1', 'S4', None],
            'R15': ['S1', 'S5', None],
            'R26': ['S2', 'S6', None],
            'R27': ['S2', 'S7', None],
            'R34': ['S3', 'S4', None],
            'R36': ['S3', 'S6', None],
            'R37': ['S3', 'S7', None],
            'R48': ['S4', 'S8', None],
            'R56': ['S5', 'S6', None],
            'R58': ['S5', 'S8', None],
            'R78': ['S7', 'S8', None]
        }

        # Select the specific combination from the dictionary
        selected_combination_routes = routes_combination.get(current_com, [])
        
        # Remove None values from the list
        selected_combination_routes = [route for route in selected_combination_routes if route is not None]
        
        # Create a sides dictionary for the selected combination
        sides = {f'side{i+1}': route for i, route in enumerate(selected_combination_routes)}

        # Construct the modes dictionary using the routes dictionary
        modes = {}
        
        for side, route in sides.items():
            # Get sensors associated with the route from the routes dictionary
            sensors = routes.get(route, [])
            # Remove None values from sensors
            sensors = [sensor for sensor in sensors if sensor is not None]
            # Create the entry for the modes dictionary
            modes[side] = [None, {sensor: None for sensor in sensors}]

        # Initialize densities dictionary for all sensors
        result = {'S1': None, 'S2': None, 'S3': None, 'S4': None, 'S5': None, 'S6': None, 'S7': None, 'S8': None}

        def get_variable(s):
            # Get the current value of the side timer from NetLogo
            return int(self.netlogo.report(f'{s}'))

        def v_count(name):
            # Safely report the vehicle count for the given light
            result = self.netlogo.report(
                f'ifelse-value (any? lights with [name = "{name}"]) [ [cars-passed] of one-of lights with [name = "{name}"] ] [ 0 ]'
            )
            return int(result)

        # Calculate the densities based on the current mode settings
        for key, value in modes.items():
            modes[key][0] = get_variable(key)  # Get the timer value for the side
            for sub_key, sub_value in value[1].items():
                vehicle_count = v_count(sub_key)  # Get the vehicle count for the light
                
                # Avoid division by zero
                if value[0] != 0:
                    result[sub_key] = round(vehicle_count / value[0], 2)
                else:
                    result[sub_key] = 0.0  # Assign a default value when there are no cars passing

        return result

    def render(self):
        # Visualization Implement is done withing the Netlogo
        pass

    def close(self):
        self.netlogo.kill_workspace()

# %%
# Initialize the environment
env = TrafficSimulation()

# %%
# Define the path for logs and save the model
log_path = os.path.join('Training', 'Logs')
model_save_path = os.path.join('Training', 'PPO_Traffic_Model')

# Create the PPO model with the 'MultiInputPolicy' for the custom environment
model = PPO(
    "MlpPolicy", 
    env, 
    verbose=1, 
    tensorboard_log=log_path
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Train the model for a specific number of timesteps  min_density = max(np.min(observation), 0.1) 
model.learn(total_timesteps=30000)
# Out:
# Logging to Training/Logs/PPO_3
# side1-counter 3 : S1 2  S4 12
# side2-counter 4 : S2 22  S7 7
# side3-counter 4 : S3 8  S6 25
# side4-counter 4 : S5 3  S8 28
# Cycle Finished at 16 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 15
# side2-counter 4 : S3 8  S4 21
# side3-counter 4 : S5 5  S6 15
# side4-counter 4 : S7 10  S8 16
# Cycle Finished at 32 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 11
# side2-counter 4 : S2 13  S7 4
# side3-counter 4 : S3 8  S6 17
# side4-counter 4 : S5 3  S8 11
# Cycle Finished at 48 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 4
# side2-counter 4 : S2 8  S6 13
# side3-counter 4 : S3 5  S4 14
# side4-counter 4 : S7 4  S8 8
# Cycle Finished at 64 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 8
# side2-counter 4 : S3 11  S4 11
# side3-counter 4 : S5 3  S6 16
# side4-counter 4 : S7 10  S8 10
# Cycle Finished at 80 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 2
# side2-counter 4 : S2 13  S7 6
# side3-counter 4 : S3 5  S6 10
# side4-counter 4 : S4 12  S8 9
# Cycle Finished at 96 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 4
# side2-counter 4 : S2 13  S6 13
# side3-counter 4 : S3 9  S7 8
# side4-counter 4 : S4 14  S8 14
# Cycle Finished at 112 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 4
# side2-counter 4 : S2 10  S6 11
# side3-counter 4 : S3 12  S4 12
# side4-counter 4 : S7 4  S8 11
# Cycle Finished at 128 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 4
# side2-counter 4 : S2 15  S6 11
# side3-counter 4 : S3 5  S4 11
# side4-counter 4 : S7 4  S8 15
# Cycle Finished at 144 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 3
# side2-counter 4 : S2 13  S7 6
# side3-counter 4 : S3 8  S6 14
# side4-counter 4 : S4 11  S8 9
# Cycle Finished at 160 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 2
# side2-counter 4 : S2 12  S7 4
# side3-counter 4 : S3 6  S6 12
# side4-counter 4 : S4 12  S8 9
# Cycle Finished at 176 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 11
# side2-counter 4 : S2 12  S7 3
# side3-counter 4 : S3 4  S6 12
# side4-counter 4 : S5 4  S8 11
# Cycle Finished at 192 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 4
# side2-counter 4 : S2 9  S7 8
# side3-counter 4 : S3 16  S6 11
# side4-counter 4 : S4 14  S8 10
# Cycle Finished at 208 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 4
# side2-counter 4 : S3 6  S4 12
# side3-counter 4 : S5 2  S6 8
# side4-counter 4 : S7 9  S8 11
# Cycle Finished at 224 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 4
# side2-counter 4 : S2 14  S6 10
# side3-counter 4 : S3 10  S7 14
# side4-counter 4 : S4 11  S8 9
# Cycle Finished at 240 in com6
# Setting min-density to 0.8
# side1-counter 3 : S1 2  S4 11
# side2-counter 4 : S2 26  S7 2
# side3-counter 4 : S3 1  S6 26
# side4-counter 4 : S5 8  S8 25
# Cycle Finished at 16 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S2 9
# side2-counter 4 : S3 2  S7 1
# side3-counter 4 : S4 16  S8 24
# side4-counter 4 : S5 11  S6 9
# Cycle Finished at 32 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 2
# side2-counter 4 : S2 16  S6 15
# side3-counter 4 : S3 2  S7 2
# side4-counter 4 : S4 11  S8 14
# Cycle Finished at 48 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 8
# side2-counter 4 : S2 11  S6 14
# side3-counter 4 : S3 1  S4 15
# side4-counter 4 : S7 8  S8 12
# Cycle Finished at 64 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 6
# side2-counter 4 : S2 8  S6 15
# side3-counter 4 : S3 2  S7 2
# side4-counter 4 : S4 14  S8 17
# Cycle Finished at 80 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S2 4
# side2-counter 4 : S3 2  S7 2
# side3-counter 4 : S4 9  S8 15
# side4-counter 4 : S5 12  S6 9
# Cycle Finished at 96 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 0
# side2-counter 4 : S2 12  S6 12
# side3-counter 4 : S3 1  S4 16
# side4-counter 4 : S7 0  S8 9
# Cycle Finished at 112 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 11
# side2-counter 4 : S3 1  S7 2
# side3-counter 4 : S4 11  S8 13
# side4-counter 4 : S5 7  S6 13
# Cycle Finished at 128 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 3
# side2-counter 4 : S2 11  S7 2
# side3-counter 4 : S3 2  S6 11
# side4-counter 4 : S4 9  S8 9
# Cycle Finished at 144 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 11
# side2-counter 4 : S2 8  S7 1
# side3-counter 4 : S3 2  S6 11
# side4-counter 4 : S5 6  S8 11
# Cycle Finished at 160 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S4 13
# side2-counter 4 : S2 17  S7 2
# side3-counter 4 : S3 2  S6 11
# side4-counter 4 : S5 7  S8 11
# Cycle Finished at 176 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 10
# side2-counter 4 : S3 1  S4 11
# side3-counter 4 : S5 6  S6 16
# side4-counter 4 : S7 2  S8 10
# Cycle Finished at 192 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 8
# side2-counter 4 : S2 9  S6 11
# side3-counter 4 : S3 1  S7 1
# side4-counter 4 : S4 14  S8 11
# Cycle Finished at 208 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 10
# side2-counter 4 : S2 10  S7 2
# side3-counter 4 : S3 2  S6 13
# side4-counter 4 : S5 6  S8 13
# Cycle Finished at 224 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 10
# side2-counter 4 : S2 12  S6 17
# side3-counter 4 : S3 2  S7 2
# side4-counter 4 : S5 6  S8 10
# Cycle Finished at 240 in com3
# Setting min-density to 0.8
# side1-counter 3 : S1 1  S4 6
# side2-counter 4 : S2 24  S7 4
# side3-counter 4 : S3 6  S6 24
# side4-counter 4 : S5 5  S8 26
# Cycle Finished at 16 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 8
# side2-counter 4 : S3 3  S4 18
# side3-counter 4 : S5 5  S6 13
# side4-counter 4 : S7 5  S8 23
# Cycle Finished at 32 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S4 10
# side2-counter 4 : S2 10  S6 15
# side3-counter 4 : S3 4  S7 7
# side4-counter 4 : S5 5  S8 9
# Cycle Finished at 48 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 5
# side2-counter 4 : S2 10  S7 5
# side3-counter 4 : S3 3  S6 11
# side4-counter 4 : S4 11  S8 7
# Cycle Finished at 64 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 4
# side2-counter 4 : S3 4  S4 8
# side3-counter 4 : S5 5  S6 14
# side4-counter 4 : S7 7  S8 11
# Cycle Finished at 80 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 11
# side2-counter 4 : S3 4  S7 1
# side3-counter 4 : S4 12  S8 14
# side4-counter 4 : S5 5  S6 10
# Cycle Finished at 96 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 9
# side2-counter 4 : S3 4  S4 11
# side3-counter 4 : S5 12  S6 11
# side4-counter 4 : S7 5  S8 9
# Cycle Finished at 112 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 13
# side2-counter 4 : S2 18  S7 1
# side3-counter 4 : S3 2  S6 9
# side4-counter 4 : S5 6  S8 8
# Cycle Finished at 128 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 3
# side2-counter 4 : S2 14  S6 9
# side3-counter 4 : S3 3  S7 5
# side4-counter 4 : S4 10  S8 8
# Cycle Finished at 144 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 9
# side2-counter 4 : S3 4  S4 10
# side3-counter 4 : S5 7  S6 8
# side4-counter 4 : S7 6  S8 11
# Cycle Finished at 160 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 5
# side2-counter 4 : S2 12  S6 11
# side3-counter 4 : S3 4  S7 5
# side4-counter 4 : S4 11  S8 9
# Cycle Finished at 176 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 5
# side2-counter 4 : S2 12  S6 8
# side3-counter 4 : S3 3  S4 10
# side4-counter 4 : S7 5  S8 11
# Cycle Finished at 192 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 4
# side2-counter 4 : S2 11  S7 6
# side3-counter 4 : S3 4  S6 12
# side4-counter 4 : S4 6  S8 13
# Cycle Finished at 208 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 9
# side2-counter 4 : S3 4  S4 14
# side3-counter 4 : S5 5  S6 13
# side4-counter 4 : S7 4  S8 9
# Cycle Finished at 224 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 8
# side2-counter 4 : S2 17  S6 15
# side3-counter 4 : S3 4  S7 4
# side4-counter 4 : S5 6  S8 15
# Cycle Finished at 240 in com3
# Setting min-density to 0.8
# side1-counter 3 : S1 2  S5 3
# side2-counter 4 : S2 25  S7 3
# side3-counter 4 : S3 6  S6 23
# side4-counter 4 : S4 25  S8 34
# Cycle Finished at 16 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 5
# side2-counter 4 : S3 6  S7 6
# side3-counter 4 : S4 19  S8 23
# side4-counter 4 : S5 6  S6 19
# Cycle Finished at 32 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 0
# side2-counter 4 : S2 13  S7 6
# side3-counter 4 : S3 9  S6 12
# side4-counter 4 : S5 4  S8 9
# Cycle Finished at 48 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 5
# side2-counter 4 : S2 4  S6 9
# side3-counter 4 : S3 6  S4 10
# side4-counter 4 : S7 5  S8 14
# Cycle Finished at 64 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S4 11
# side2-counter 4 : S2 13  S6 13
# side3-counter 4 : S3 9  S7 6
# side4-counter 4 : S5 6  S8 11
# Cycle Finished at 80 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 13
# side2-counter 4 : S3 11  S4 18
# side3-counter 4 : S5 5  S6 13
# side4-counter 4 : S7 5  S8 7
# Cycle Finished at 96 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 6
# side2-counter 4 : S2 11  S7 6
# side3-counter 4 : S3 7  S6 11
# side4-counter 4 : S4 9  S8 10
# Cycle Finished at 112 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 4
# side2-counter 4 : S2 14  S6 10
# side3-counter 4 : S3 8  S7 4
# side4-counter 4 : S4 13  S8 12
# Cycle Finished at 128 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 6
# side2-counter 4 : S2 8  S7 5
# side3-counter 4 : S3 8  S6 10
# side4-counter 4 : S4 14  S8 9
# Cycle Finished at 144 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 4
# side2-counter 4 : S2 10  S6 14
# side3-counter 4 : S3 9  S7 6
# side4-counter 4 : S4 10  S8 13
# Cycle Finished at 160 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 8
# side2-counter 4 : S2 17  S6 9
# side3-counter 4 : S3 9  S4 10
# side4-counter 4 : S7 8  S8 13
# Cycle Finished at 176 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 11
# side2-counter 4 : S3 8  S7 3
# side3-counter 4 : S4 12  S8 11
# side4-counter 4 : S5 5  S6 9
# Cycle Finished at 192 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 12
# side2-counter 4 : S3 6  S7 6
# side3-counter 4 : S4 11  S8 11
# side4-counter 4 : S5 5  S6 13
# Cycle Finished at 208 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 16
# side2-counter 4 : S3 7  S4 9
# side3-counter 4 : S5 6  S6 10
# side4-counter 4 : S7 6  S8 20
# Cycle Finished at 224 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 6
# side2-counter 4 : S2 7  S6 12
# side3-counter 4 : S3 7  S4 12
# side4-counter 4 : S7 6  S8 10
# Cycle Finished at 240 in com5
# Setting min-density to 0.8
# side1-counter 3 : S1 1  S2 21
# side2-counter 4 : S3 2  S7 3
# side3-counter 4 : S4 26  S8 22
# side4-counter 4 : S5 0  S6 24
# Cycle Finished at 16 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 0
# side2-counter 4 : S2 10  S6 8
# side3-counter 4 : S3 5  S4 11
# side4-counter 4 : S7 0  S8 22
# Cycle Finished at 32 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 12
# side2-counter 4 : S3 6  S7 5
# side3-counter 4 : S4 7  S8 15
# side4-counter 4 : S5 0  S6 9
# Cycle Finished at 48 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 0
# side2-counter 4 : S2 9  S6 13
# side3-counter 4 : S3 6  S4 13
# side4-counter 4 : S7 0  S8 14
# Cycle Finished at 64 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 12
# side2-counter 4 : S3 5  S4 8
# side3-counter 4 : S5 0  S6 10
# side4-counter 4 : S7 5  S8 11
# Cycle Finished at 80 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 0
# side2-counter 4 : S2 13  S7 5
# side3-counter 4 : S3 6  S6 13
# side4-counter 4 : S4 10  S8 15
# Cycle Finished at 96 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 0
# side2-counter 4 : S2 10  S6 13
# side3-counter 4 : S3 5  S4 6
# side4-counter 4 : S7 0  S8 12
# Cycle Finished at 112 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 15
# side2-counter 4 : S2 12  S7 3
# side3-counter 4 : S3 6  S6 11
# side4-counter 4 : S5 0  S8 15
# Cycle Finished at 128 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 0
# side2-counter 4 : S2 8  S6 11
# side3-counter 4 : S3 6  S4 12
# side4-counter 4 : S7 0  S8 8
# Cycle Finished at 144 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S4 13
# side2-counter 4 : S2 12  S7 5
# side3-counter 4 : S3 7  S6 13
# side4-counter 4 : S5 0  S8 9
# Cycle Finished at 160 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 13
# side2-counter 4 : S2 11  S7 6
# side3-counter 4 : S3 4  S6 9
# side4-counter 4 : S5 0  S8 11
# Cycle Finished at 176 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 8
# side2-counter 4 : S3 5  S4 9
# side3-counter 4 : S5 0  S6 14
# side4-counter 4 : S7 7  S8 11
# Cycle Finished at 192 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 0
# side2-counter 4 : S2 10  S7 3
# side3-counter 4 : S3 6  S6 13
# side4-counter 4 : S4 9  S8 10
# Cycle Finished at 208 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 0
# side2-counter 4 : S2 10  S6 11
# side3-counter 4 : S3 5  S4 16
# side4-counter 4 : S7 0  S8 11
# Cycle Finished at 224 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 10
# side2-counter 4 : S2 11  S6 14
# side3-counter 4 : S3 5  S7 14
# side4-counter 4 : S5 0  S8 14
# Cycle Finished at 240 in com3
# Setting min-density to 0.8
# side1-counter 3 : S1 3  S2 24
# side2-counter 4 : S3 6  S4 24
# side3-counter 4 : S5 1  S6 24
# side4-counter 4 : S7 10  S8 26
# Cycle Finished at 16 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S4 18
# side2-counter 4 : S2 12  S6 9
# side3-counter 4 : S3 5  S7 9
# side4-counter 4 : S5 2  S8 26
# Cycle Finished at 32 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 14
# side2-counter 4 : S2 11  S7 8
# side3-counter 4 : S3 7  S6 7
# side4-counter 4 : S5 2  S8 12
# Cycle Finished at 48 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S2 6
# side2-counter 4 : S3 5  S4 17
# side3-counter 4 : S5 1  S6 8
# side4-counter 4 : S7 9  S8 11
# Cycle Finished at 64 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 2
# side2-counter 4 : S2 14  S6 13
# side3-counter 4 : S3 5  S4 12
# side4-counter 4 : S7 2  S8 10
# Cycle Finished at 80 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 2
# side2-counter 4 : S2 15  S7 3
# side3-counter 4 : S3 6  S6 17
# side4-counter 4 : S4 12  S8 15
# Cycle Finished at 96 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 1
# side2-counter 4 : S2 9  S6 10
# side3-counter 4 : S3 6  S7 6
# side4-counter 4 : S4 14  S8 10
# Cycle Finished at 112 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 13
# side2-counter 4 : S2 11  S7 15
# side3-counter 4 : S3 5  S6 9
# side4-counter 4 : S5 2  S8 10
# Cycle Finished at 128 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 1
# side2-counter 4 : S2 12  S6 13
# side3-counter 4 : S3 5  S4 12
# side4-counter 4 : S7 1  S8 11
# Cycle Finished at 144 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S4 15
# side2-counter 4 : S2 11  S7 3
# side3-counter 4 : S3 6  S6 11
# side4-counter 4 : S5 2  S8 17
# Cycle Finished at 160 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 8
# side2-counter 4 : S2 13  S7 8
# side3-counter 4 : S3 5  S6 15
# side4-counter 4 : S5 2  S8 11
# Cycle Finished at 176 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 9
# side2-counter 4 : S2 9  S6 17
# side3-counter 4 : S3 7  S7 9
# side4-counter 4 : S5 2  S8 14
# Cycle Finished at 192 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S2 12
# side2-counter 4 : S3 7  S7 7
# side3-counter 4 : S4 13  S8 10
# side4-counter 4 : S5 1  S6 12
# Cycle Finished at 208 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 2
# side2-counter 4 : S2 13  S6 10
# side3-counter 4 : S3 8  S4 11
# side4-counter 4 : S7 2  S8 16
# Cycle Finished at 224 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 2
# side2-counter 4 : S2 12  S7 6
# side3-counter 4 : S3 4  S6 15
# side4-counter 4 : S4 10  S8 14
# Cycle Finished at 240 in com7
# Setting min-density to 0.8
# side1-counter 3 : S1 3  S4 21
# side2-counter 4 : S2 25  S6 28
# side3-counter 4 : S3 7  S7 5
# side4-counter 4 : S5 5  S8 25
# Cycle Finished at 16 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S4 18
# side2-counter 4 : S2 13  S7 7
# side3-counter 4 : S3 10  S6 13
# side4-counter 4 : S5 6  S8 22
# Cycle Finished at 32 in com4
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S2 10
# side2-counter 4 : S3 9  S7 5
# side3-counter 4 : S4 15  S8 10
# side4-counter 4 : S5 4  S6 14
# Cycle Finished at 48 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S2 12
# side2-counter 4 : S3 8  S7 8
# side3-counter 4 : S4 11  S8 10
# side4-counter 4 : S5 10  S6 11
# Cycle Finished at 64 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S2 12
# side2-counter 4 : S3 4  S7 7
# side3-counter 4 : S4 12  S8 9
# side4-counter 4 : S5 5  S6 8
# Cycle Finished at 80 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 6  S4 3
# side2-counter 4 : S2 10  S6 11
# side3-counter 4 : S3 9  S7 9
# side4-counter 4 : S5 6  S8 10
# Cycle Finished at 96 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S5 4
# side2-counter 4 : S2 2  S7 6
# side3-counter 4 : S3 7  S6 12
# side4-counter 4 : S4 14  S8 8
# Cycle Finished at 112 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 5
# side2-counter 4 : S2 13  S6 9
# side3-counter 4 : S3 9  S4 12
# side4-counter 4 : S7 5  S8 14
# Cycle Finished at 128 in com5
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S2 15
# side2-counter 4 : S3 8  S4 13
# side3-counter 4 : S5 6  S6 10
# side4-counter 4 : S7 7  S8 10
# Cycle Finished at 144 in com1
# Setting min-density to 1.25
# side1-counter 4 : S1 7  S5 5
# side2-counter 4 : S2 11  S6 12
# side3-counter 4 : S3 8  S4 7
# side4-counter 4 : S7 5  S8 14
# Cycle Finished at 160 in com5
# Setting min-density to 1.25
# side1-counter 4 : S1 6  S4 13
# side2-counter 4 : S2 11  S7 6
# side3-counter 4 : S3 9  S6 14
# side4-counter 4 : S5 5  S8 15
# Cycle Finished at 176 in com4
# Setting min-density to 1.25
# side1-counter 4 : S1 4  S5 2
# side2-counter 4 : S2 8  S6 12
# side3-counter 4 : S3 11  S4 16
# side4-counter 4 : S7 2  S8 12
# Cycle Finished at 192 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S4 13
# side2-counter 4 : S2 12  S6 10
# side3-counter 4 : S3 9  S7 7
# side4-counter 4 : S5 3  S8 9
# Cycle Finished at 208 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S2 12
# side2-counter 4 : S3 10  S7 6
# side3-counter 4 : S4 11  S8 9
# side4-counter 4 : S5 7  S6 11
# Cycle Finished at 224 in com2
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S5 5
# side2-counter 4 : S2 11  S6 11
# side3-counter 4 : S3 8  S7 9
# side4-counter 4 : S4 11  S8 9
# Cycle Finished at 240 in com6
# Setting min-density to 1.25
# side1-counter 3 : S1 2  S2 20
# side2-counter 4 : S3 7  S7 8
# side3-counter 4 : S4 30  S8 28
# side4-counter 4 : S5 4  S6 26
# Cycle Finished at 16 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S4 8
# side2-counter 4 : S2 14  S7 10
# side3-counter 4 : S3 8  S6 14
# side4-counter 4 : S5 4  S8 19
# Cycle Finished at 32 in com4
# Setting min-density to 1.0
# side1-counter 4 : S1 7  S4 10
# side2-counter 4 : S2 7  S7 10
# side3-counter 4 : S3 11  S6 12
# side4-counter 4 : S5 2  S8 18
# Cycle Finished at 48 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S5 4
# side2-counter 4 : S2 8  S6 8
# side3-counter 4 : S3 9  S4 10
# side4-counter 4 : S7 4  S8 8
# Cycle Finished at 64 in com5
# Setting min-density to 1.0
# side1-counter 4 : S1 6  S2 14
# side2-counter 4 : S3 14  S7 4
# side3-counter 4 : S4 17  S8 12
# side4-counter 4 : S5 3  S6 10
# Cycle Finished at 80 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 3
# side2-counter 4 : S2 10  S6 9
# side3-counter 4 : S3 8  S7 11
# side4-counter 4 : S4 13  S8 14
# Cycle Finished at 96 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S4 8
# side2-counter 4 : S2 10  S6 9
# side3-counter 4 : S3 16  S7 10
# side4-counter 4 : S5 3  S8 11
# Cycle Finished at 112 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S4 9
# side2-counter 4 : S2 12  S6 11
# side3-counter 4 : S3 9  S7 9
# side4-counter 4 : S5 4  S8 10
# Cycle Finished at 128 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S4 9
# side2-counter 4 : S2 12  S7 7
# side3-counter 4 : S3 11  S6 10
# side4-counter 4 : S5 4  S8 12
# Cycle Finished at 144 in com4
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S2 8
# side2-counter 4 : S3 9  S4 10
# side3-counter 4 : S5 3  S6 11
# side4-counter 4 : S7 13  S8 10
# Cycle Finished at 160 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S2 10
# side2-counter 4 : S3 9  S7 4
# side3-counter 4 : S4 10  S8 26
# side4-counter 4 : S5 4  S6 16
# Cycle Finished at 176 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 6  S4 3
# side2-counter 4 : S2 6  S6 13
# side3-counter 4 : S3 8  S7 7
# side4-counter 4 : S5 4  S8 10
# Cycle Finished at 192 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S4 12
# side2-counter 4 : S2 10  S6 10
# side3-counter 4 : S3 9  S7 12
# side4-counter 4 : S5 3  S8 8
# Cycle Finished at 208 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S5 3
# side2-counter 4 : S2 10  S7 6
# side3-counter 4 : S3 7  S6 10
# side4-counter 4 : S4 10  S8 10
# Cycle Finished at 224 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S2 4
# side2-counter 4 : S3 10  S4 12
# side3-counter 4 : S5 4  S6 12
# side4-counter 4 : S7 10  S8 14
# Cycle Finished at 240 in com1
# Setting min-density to 1.0
# side1-counter 3 : S1 4  S5 2
# side2-counter 4 : S2 24  S6 26
# side3-counter 4 : S3 4  S4 20
# side4-counter 4 : S7 3  S8 23
# Cycle Finished at 16 in com5
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S5 4
# side2-counter 4 : S2 7  S6 10
# side3-counter 4 : S3 2  S7 10
# side4-counter 4 : S4 18  S8 19
# Cycle Finished at 32 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S2 5
# side2-counter 4 : S3 4  S4 17
# side3-counter 4 : S5 7  S6 8
# side4-counter 4 : S7 8  S8 9
# Cycle Finished at 48 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S2 9
# side2-counter 4 : S3 3  S7 3
# side3-counter 4 : S4 15  S8 9
# side4-counter 4 : S5 9  S6 10
# Cycle Finished at 64 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S4 2
# side2-counter 4 : S2 10  S7 9
# side3-counter 4 : S3 4  S6 8
# side4-counter 4 : S5 4  S8 15
# Cycle Finished at 80 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 5
# side2-counter 4 : S2 10  S7 9
# side3-counter 4 : S3 4  S6 11
# side4-counter 4 : S4 15  S8 11
# Cycle Finished at 96 in com7
# Setting min-density to 1.0
# side1-counter 4 : S1 7  S5 6
# side2-counter 4 : S2 11  S6 14
# side3-counter 4 : S3 6  S4 15
# side4-counter 4 : S7 6  S8 14
# Cycle Finished at 112 in com5
# Setting min-density to 1.5
# side1-counter 4 : S1 6  S4 11
# side2-counter 4 : S2 10  S7 4
# side3-counter 4 : S3 4  S6 11
# side4-counter 4 : S5 4  S8 13
# Cycle Finished at 128 in com4
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S4 9
# side2-counter 4 : S2 12  S6 11
# side3-counter 4 : S3 2  S7 10
# side4-counter 4 : S5 5  S8 13
# Cycle Finished at 144 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 4
# side2-counter 4 : S2 17  S6 11
# side3-counter 4 : S3 4  S7 10
# side4-counter 4 : S4 13  S8 9
# Cycle Finished at 160 in com6
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S5 7
# side2-counter 4 : S2 10  S6 12
# side3-counter 4 : S3 4  S7 9
# side4-counter 4 : S4 14  S8 12
# Cycle Finished at 176 in com6
# Setting min-density to 1.0
# side1-counter 4 : S1 7  S4 17
# side2-counter 4 : S2 9  S6 13
# side3-counter 4 : S3 3  S7 8
# side4-counter 4 : S5 6  S8 14
# Cycle Finished at 192 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 2
# side2-counter 4 : S2 10  S7 10
# side3-counter 4 : S3 4  S6 13
# side4-counter 4 : S4 10  S8 12
# Cycle Finished at 208 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S5 6
# side2-counter 4 : S2 15  S7 8
# side3-counter 4 : S3 3  S6 11
# side4-counter 4 : S4 12  S8 9
# Cycle Finished at 224 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S2 7
# side2-counter 4 : S3 3  S4 13
# side3-counter 4 : S5 5  S6 15
# side4-counter 4 : S7 9  S8 10
# Cycle Finished at 240 in com1
# Setting min-density to 0.8
# side1-counter 3 : S1 4  S4 10
# side2-counter 4 : S2 27  S7 7
# side3-counter 4 : S3 9  S6 21
# side4-counter 4 : S5 6  S8 25
# Cycle Finished at 16 in com4
# Setting min-density to 1.33
# side1-counter 4 : S1 4  S5 3
# side2-counter 4 : S2 4  S7 6
# side3-counter 4 : S3 6  S6 8
# side4-counter 4 : S4 22  S8 21
# Cycle Finished at 32 in com7
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S4 11
# side2-counter 4 : S2 9  S7 7
# side3-counter 4 : S3 5  S6 15
# side4-counter 4 : S5 6  S8 11
# Cycle Finished at 48 in com4
# Setting min-density to 1.25
# side1-counter 4 : S1 6  S5 4
# side2-counter 4 : S2 11  S6 9
# side3-counter 4 : S3 8  S7 7
# side4-counter 4 : S4 13  S8 10
# Cycle Finished at 64 in com6
# Setting min-density to 1.0
# side1-counter 4 : S1 6  S5 5
# side2-counter 4 : S2 16  S6 12
# side3-counter 4 : S3 8  S4 11
# side4-counter 4 : S7 5  S8 8
# Cycle Finished at 80 in com5
# Setting min-density to 1.25
# side1-counter 4 : S1 8  S2 14
# side2-counter 4 : S3 8  S7 4
# side3-counter 4 : S4 13  S8 14
# side4-counter 4 : S5 4  S6 10
# Cycle Finished at 96 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S5 4
# side2-counter 4 : S2 11  S7 8
# side3-counter 4 : S3 8  S6 13
# side4-counter 4 : S4 12  S8 9
# Cycle Finished at 112 in com7
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S5 6
# side2-counter 4 : S2 16  S7 6
# side3-counter 4 : S3 7  S6 10
# side4-counter 4 : S4 11  S8 10
# Cycle Finished at 128 in com7
# Setting min-density to 1.25
# side1-counter 4 : S1 6  S4 5
# side2-counter 4 : S2 10  S6 15
# side3-counter 4 : S3 9  S7 7
# side4-counter 4 : S5 4  S8 8
# Cycle Finished at 144 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 8  S4 12
# side2-counter 4 : S2 13  S7 7
# side3-counter 4 : S3 13  S6 10
# side4-counter 4 : S5 5  S8 14
# Cycle Finished at 160 in com4
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S4 12
# side2-counter 4 : S2 12  S7 5
# side3-counter 4 : S3 7  S6 11
# side4-counter 4 : S5 5  S8 9
# Cycle Finished at 176 in com4
# Setting min-density to 1.25
# side1-counter 4 : S1 4  S5 4
# side2-counter 4 : S2 7  S7 7
# side3-counter 4 : S3 7  S6 10
# side4-counter 4 : S4 11  S8 8
# Cycle Finished at 192 in com7
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S2 5
# side2-counter 4 : S3 7  S7 7
# side3-counter 4 : S4 16  S8 8
# side4-counter 4 : S5 4  S6 12
# Cycle Finished at 208 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S4 9
# side2-counter 4 : S2 13  S7 6
# side3-counter 4 : S3 6  S6 12
# side4-counter 4 : S5 6  S8 10
# Cycle Finished at 224 in com4
# Setting min-density to 1.25
# side1-counter 4 : S1 8  S4 10
# side2-counter 4 : S2 16  S6 9
# side3-counter 4 : S3 7  S7 8
# side4-counter 4 : S5 5  S8 10
# Cycle Finished at 240 in com3
# Setting min-density to 1.25
# side1-counter 3 : S1 3  S5 6
# side2-counter 4 : S2 29  S6 23
# side3-counter 4 : S3 2  S4 28
# side4-counter 4 : S7 6  S8 25
# Cycle Finished at 16 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 10  S4 20
# side2-counter 4 : S2 16  S7 3
# side3-counter 4 : S3 0  S6 11
# side4-counter 4 : S5 7  S8 23
# Cycle Finished at 32 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S5 3
# side2-counter 4 : S2 10  S7 3
# side3-counter 4 : S3 0  S6 8
# side4-counter 4 : S4 12  S8 12
# Cycle Finished at 48 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S4 16
# side2-counter 4 : S2 15  S6 14
# side3-counter 4 : S3 0  S7 4
# side4-counter 4 : S5 6  S8 13
# Cycle Finished at 64 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 10  S2 14
# side2-counter 4 : S3 0  S7 4
# side3-counter 4 : S4 12  S8 10
# side4-counter 4 : S5 8  S6 13
# Cycle Finished at 80 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S5 5
# side2-counter 4 : S2 9  S6 13
# side3-counter 4 : S3 0  S4 12
# side4-counter 4 : S7 5  S8 11
# Cycle Finished at 96 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 9  S2 12
# side2-counter 4 : S3 0  S4 15
# side3-counter 4 : S5 9  S6 17
# side4-counter 4 : S7 4  S8 10
# Cycle Finished at 112 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 12  S5 5
# side2-counter 4 : S2 10  S6 16
# side3-counter 4 : S3 0  S7 4
# side4-counter 4 : S4 10  S8 8
# Cycle Finished at 128 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S5 10
# side2-counter 4 : S2 12  S6 11
# side3-counter 4 : S3 0  S4 13
# side4-counter 4 : S7 10  S8 10
# Cycle Finished at 144 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S4 14
# side2-counter 4 : S2 10  S6 12
# side3-counter 4 : S3 0  S7 4
# side4-counter 4 : S5 7  S8 10
# Cycle Finished at 160 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S2 13
# side2-counter 4 : S3 0  S7 4
# side3-counter 4 : S4 18  S8 10
# side4-counter 4 : S5 6  S6 11
# Cycle Finished at 176 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S4 2
# side2-counter 4 : S2 15  S7 3
# side3-counter 4 : S3 0  S6 14
# side4-counter 4 : S5 10  S8 10
# Cycle Finished at 192 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 12  S5 3
# side2-counter 4 : S2 2  S6 12
# side3-counter 4 : S3 0  S7 4
# side4-counter 4 : S4 10  S8 15
# Cycle Finished at 208 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 10  S5 4
# side2-counter 4 : S2 13  S7 3
# side3-counter 4 : S3 0  S6 12
# side4-counter 4 : S4 13  S8 13
# Cycle Finished at 224 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S5 8
# side2-counter 4 : S2 9  S6 11
# side3-counter 4 : S3 0  S4 14
# side4-counter 4 : S7 8  S8 10
# Cycle Finished at 240 in com5
# Setting min-density to 0.8
# side1-counter 3 : S1 4  S2 8
# side2-counter 4 : S3 8  S4 28
# side3-counter 4 : S5 4  S6 23
# side4-counter 4 : S7 3  S8 25
# Cycle Finished at 16 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S4 12
# side2-counter 4 : S2 20  S7 4
# side3-counter 4 : S3 8  S6 9
# side4-counter 4 : S5 1  S8 18
# Cycle Finished at 32 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S2 14
# side2-counter 4 : S3 10  S4 11
# side3-counter 4 : S5 1  S6 12
# side4-counter 4 : S7 3  S8 16
# Cycle Finished at 48 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S4 5
# side2-counter 4 : S2 17  S6 25
# side3-counter 4 : S3 9  S7 2
# side4-counter 4 : S5 2  S8 13
# Cycle Finished at 64 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S2 11
# side2-counter 4 : S3 9  S4 9
# side3-counter 4 : S5 2  S6 12
# side4-counter 4 : S7 3  S8 10
# Cycle Finished at 80 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S5 2
# side2-counter 4 : S2 12  S6 12
# side3-counter 4 : S3 18  S4 9
# side4-counter 4 : S7 2  S8 10
# Cycle Finished at 96 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S2 12
# side2-counter 4 : S3 7  S7 4
# side3-counter 4 : S4 10  S8 12
# side4-counter 4 : S5 1  S6 11
# Cycle Finished at 112 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S4 2
# side2-counter 4 : S2 15  S6 15
# side3-counter 4 : S3 11  S7 2
# side4-counter 4 : S5 1  S8 11
# Cycle Finished at 128 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 2
# side2-counter 4 : S2 5  S6 8
# side3-counter 4 : S3 10  S4 14
# side4-counter 4 : S7 2  S8 13
# Cycle Finished at 144 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S4 10
# side2-counter 4 : S2 11  S7 4
# side3-counter 4 : S3 10  S6 10
# side4-counter 4 : S5 2  S8 5
# Cycle Finished at 160 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S4 12
# side2-counter 4 : S2 11  S7 4
# side3-counter 4 : S3 8  S6 8
# side4-counter 4 : S5 1  S8 12
# Cycle Finished at 176 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 2
# side2-counter 4 : S2 15  S6 15
# side3-counter 4 : S3 8  S4 12
# side4-counter 4 : S7 2  S8 14
# Cycle Finished at 192 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S2 7
# side2-counter 4 : S3 9  S7 3
# side3-counter 4 : S4 15  S8 11
# side4-counter 4 : S5 2  S6 9
# Cycle Finished at 208 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S2 13
# side2-counter 4 : S3 9  S4 15
# side3-counter 4 : S5 1  S6 12
# side4-counter 4 : S7 3  S8 14
# Cycle Finished at 224 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 1
# side2-counter 4 : S2 12  S7 4
# side3-counter 4 : S3 9  S6 17
# side4-counter 4 : S4 13  S8 12
# Cycle Finished at 240 in com7
# Setting min-density to 0.8
# side1-counter 3 : S1 3  S2 18
# side2-counter 4 : S3 6  S7 5
# side3-counter 4 : S4 22  S8 25
# side4-counter 4 : S5 8  S6 26
# Cycle Finished at 16 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 2  S5 6
# side2-counter 4 : S2 15  S6 9
# side3-counter 4 : S3 11  S7 8
# side4-counter 4 : S4 15  S8 19
# Cycle Finished at 32 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 7
# side2-counter 4 : S2 9  S6 10
# side3-counter 4 : S3 5  S7 6
# side4-counter 4 : S4 15  S8 13
# Cycle Finished at 48 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 7
# side2-counter 4 : S2 13  S6 13
# side3-counter 4 : S3 4  S4 14
# side4-counter 4 : S7 7  S8 14
# Cycle Finished at 64 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 7
# side2-counter 4 : S2 11  S7 7
# side3-counter 4 : S3 5  S6 11
# side4-counter 4 : S4 14  S8 9
# Cycle Finished at 80 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 11
# side2-counter 4 : S3 6  S4 15
# side3-counter 4 : S5 7  S6 10
# side4-counter 4 : S7 8  S8 10
# Cycle Finished at 96 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S4 6
# side2-counter 4 : S2 17  S6 6
# side3-counter 4 : S3 4  S7 7
# side4-counter 4 : S5 8  S8 14
# Cycle Finished at 112 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 14
# side2-counter 4 : S2 15  S7 8
# side3-counter 4 : S3 6  S6 11
# side4-counter 4 : S5 5  S8 9
# Cycle Finished at 128 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 2
# side2-counter 4 : S2 11  S7 5
# side3-counter 4 : S3 5  S6 17
# side4-counter 4 : S4 16  S8 14
# Cycle Finished at 144 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 6
# side2-counter 4 : S2 9  S7 7
# side3-counter 4 : S3 6  S6 13
# side4-counter 4 : S5 8  S8 14
# Cycle Finished at 160 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 9
# side2-counter 4 : S2 10  S6 9
# side3-counter 4 : S3 6  S7 9
# side4-counter 4 : S5 5  S8 10
# Cycle Finished at 176 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 15
# side2-counter 4 : S3 5  S7 6
# side3-counter 4 : S4 16  S8 12
# side4-counter 4 : S5 10  S6 14
# Cycle Finished at 192 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 16
# side2-counter 4 : S3 7  S7 7
# side3-counter 4 : S4 14  S8 14
# side4-counter 4 : S5 7  S6 18
# Cycle Finished at 208 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 17
# side2-counter 4 : S3 6  S7 6
# side3-counter 4 : S4 6  S8 11
# side4-counter 4 : S5 7  S6 14
# Cycle Finished at 224 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 8
# side2-counter 4 : S3 3  S4 3
# side3-counter 4 : S5 6  S6 19
# side4-counter 4 : S7 6  S8 13
# Cycle Finished at 240 in com1
# Setting min-density to 0.8
# side1-counter 3 : S1 4  S2 16
# side2-counter 4 : S3 8  S4 24
# side3-counter 4 : S5 4  S6 27
# side4-counter 4 : S7 8  S8 26
# Cycle Finished at 16 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 7  S4 13
# side2-counter 4 : S2 9  S7 6
# side3-counter 4 : S3 6  S6 10
# side4-counter 4 : S5 3  S8 20
# Cycle Finished at 32 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S5 3
# side2-counter 4 : S2 10  S6 11
# side3-counter 4 : S3 5  S4 10
# side4-counter 4 : S7 3  S8 9
# Cycle Finished at 48 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S4 14
# side2-counter 4 : S2 14  S6 10
# side3-counter 4 : S3 7  S7 6
# side4-counter 4 : S5 4  S8 12
# Cycle Finished at 64 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S2 14
# side2-counter 4 : S3 8  S4 13
# side3-counter 4 : S5 4  S6 11
# side4-counter 4 : S7 7  S8 16
# Cycle Finished at 80 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S5 4
# side2-counter 4 : S2 8  S6 11
# side3-counter 4 : S3 6  S4 11
# side4-counter 4 : S7 4  S8 11
# Cycle Finished at 96 in com5
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S4 14
# side2-counter 4 : S2 13  S7 5
# side3-counter 4 : S3 15  S6 12
# side4-counter 4 : S5 2  S8 10
# Cycle Finished at 112 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 3
# side2-counter 4 : S2 10  S6 10
# side3-counter 4 : S3 8  S7 6
# side4-counter 4 : S4 15  S8 15
# Cycle Finished at 128 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 5
# side2-counter 4 : S3 5  S4 13
# side3-counter 4 : S5 4  S6 8
# side4-counter 4 : S7 6  S8 10
# Cycle Finished at 144 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S2 9
# side2-counter 4 : S3 5  S4 10
# side3-counter 4 : S5 3  S6 9
# side4-counter 4 : S7 9  S8 8
# Cycle Finished at 160 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S2 10
# side2-counter 4 : S3 9  S7 3
# side3-counter 4 : S4 16  S8 13
# side4-counter 4 : S5 3  S6 15
# Cycle Finished at 176 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 4
# side2-counter 4 : S2 11  S6 8
# side3-counter 4 : S3 9  S4 9
# side4-counter 4 : S7 4  S8 11
# Cycle Finished at 192 in com5
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S2 9
# side2-counter 4 : S3 7  S4 9
# side3-counter 4 : S5 3  S6 10
# side4-counter 4 : S7 5  S8 10
# Cycle Finished at 208 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S4 13
# side2-counter 4 : S2 15  S7 4
# side3-counter 4 : S3 11  S6 12
# side4-counter 4 : S5 3  S8 6
# Cycle Finished at 224 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S2 13
# side2-counter 4 : S3 9  S7 8
# side3-counter 4 : S4 12  S8 12
# side4-counter 4 : S5 4  S6 13
# Cycle Finished at 240 in com2
# Setting min-density to 1.0
# side1-counter 3 : S1 5  S5 2
# side2-counter 4 : S2 23  S6 22
# side3-counter 4 : S3 2  S4 26
# side4-counter 4 : S7 2  S8 24
# Cycle Finished at 16 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S5 2
# side2-counter 4 : S2 9  S6 11
# side3-counter 4 : S3 1  S4 16
# side4-counter 4 : S7 2  S8 23
# Cycle Finished at 32 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S5 1
# side2-counter 4 : S2 15  S7 5
# side3-counter 4 : S3 2  S6 14
# side4-counter 4 : S4 12  S8 8
# Cycle Finished at 48 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 8
# side2-counter 4 : S2 12  S6 8
# side3-counter 4 : S3 2  S7 5
# side4-counter 4 : S5 2  S8 15
# Cycle Finished at 64 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 10  S5 2
# side2-counter 4 : S2 7  S6 10
# side3-counter 4 : S3 2  S7 8
# side4-counter 4 : S4 8  S8 10
# Cycle Finished at 80 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 10  S5 1
# side2-counter 4 : S2 9  S6 14
# side3-counter 4 : S3 1  S7 9
# side4-counter 4 : S4 15  S8 12
# Cycle Finished at 96 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S2 4
# side2-counter 4 : S3 1  S4 11
# side3-counter 4 : S5 2  S6 12
# side4-counter 4 : S7 10  S8 9
# Cycle Finished at 112 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 1
# side2-counter 4 : S2 10  S6 10
# side3-counter 4 : S3 2  S4 15
# side4-counter 4 : S7 1  S8 12
# Cycle Finished at 128 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S2 12
# side2-counter 4 : S3 2  S4 11
# side3-counter 4 : S5 2  S6 9
# side4-counter 4 : S7 8  S8 9
# Cycle Finished at 144 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S5 2
# side2-counter 4 : S2 9  S6 9
# side3-counter 4 : S3 1  S7 7
# side4-counter 4 : S4 10  S8 9
# Cycle Finished at 160 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 9  S4 16
# side2-counter 4 : S2 13  S6 9
# side3-counter 4 : S3 2  S7 12
# side4-counter 4 : S5 1  S8 13
# Cycle Finished at 176 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S2 14
# side2-counter 4 : S3 2  S4 13
# side3-counter 4 : S5 1  S6 11
# side4-counter 4 : S7 9  S8 11
# Cycle Finished at 192 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 2
# side2-counter 4 : S2 11  S6 13
# side3-counter 4 : S3 2  S7 9
# side4-counter 4 : S4 12  S8 12
# Cycle Finished at 208 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S4 17
# side2-counter 4 : S2 11  S6 8
# side3-counter 4 : S3 2  S7 10
# side4-counter 4 : S5 2  S8 11
# Cycle Finished at 224 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S4 11
# side2-counter 4 : S2 17  S7 14
# side3-counter 4 : S3 2  S6 12
# side4-counter 4 : S5 1  S8 10
# Cycle Finished at 240 in com4
# Setting min-density to 0.8
# side1-counter 3 : S1 2  S5 3
# side2-counter 4 : S2 21  S7 4
# side3-counter 4 : S3 2  S6 20
# side4-counter 4 : S4 24  S8 29
# Cycle Finished at 16 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 5
# side2-counter 4 : S2 11  S6 10
# side3-counter 4 : S3 4  S4 12
# side4-counter 4 : S7 5  S8 17
# Cycle Finished at 32 in com5
# Setting min-density to 1.0
# side1-counter 4 : S1 2  S4 10
# side2-counter 4 : S2 12  S6 7
# side3-counter 4 : S3 5  S7 6
# side4-counter 4 : S5 5  S8 10
# Cycle Finished at 48 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 3
# side2-counter 4 : S2 12  S6 10
# side3-counter 4 : S3 3  S7 7
# side4-counter 4 : S4 11  S8 10
# Cycle Finished at 64 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 11
# side2-counter 4 : S2 15  S7 6
# side3-counter 4 : S3 4  S6 15
# side4-counter 4 : S5 4  S8 10
# Cycle Finished at 80 in com4
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S2 8
# side2-counter 4 : S3 4  S7 5
# side3-counter 4 : S4 12  S8 10
# side4-counter 4 : S5 6  S6 13
# Cycle Finished at 96 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 2  S5 5
# side2-counter 4 : S2 13  S7 4
# side3-counter 4 : S3 4  S6 11
# side4-counter 4 : S4 10  S8 18
# Cycle Finished at 112 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 5
# side2-counter 4 : S2 13  S7 6
# side3-counter 4 : S3 4  S6 12
# side4-counter 4 : S5 4  S8 10
# Cycle Finished at 128 in com4
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S2 4
# side2-counter 4 : S3 2  S4 10
# side3-counter 4 : S5 6  S6 8
# side4-counter 4 : S7 5  S8 12
# Cycle Finished at 144 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 16
# side2-counter 4 : S2 9  S7 3
# side3-counter 4 : S3 4  S6 14
# side4-counter 4 : S5 4  S8 15
# Cycle Finished at 160 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 7
# side2-counter 4 : S3 4  S7 6
# side3-counter 4 : S4 11  S8 10
# side4-counter 4 : S5 6  S6 14
# Cycle Finished at 176 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 3  S4 2
# side2-counter 4 : S2 12  S7 6
# side3-counter 4 : S3 3  S6 10
# side4-counter 4 : S5 4  S8 13
# Cycle Finished at 192 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 5
# side2-counter 4 : S2 2  S6 15
# side3-counter 4 : S3 3  S7 5
# side4-counter 4 : S4 11  S8 13
# Cycle Finished at 208 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 13
# side2-counter 4 : S2 11  S6 13
# side3-counter 4 : S3 4  S7 5
# side4-counter 4 : S5 6  S8 6
# Cycle Finished at 224 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 2  S5 0
# side2-counter 4 : S2 12  S6 11
# side3-counter 4 : S3 4  S4 12
# side4-counter 4 : S7 0  S8 11
# Cycle Finished at 240 in com5
# Setting min-density to 0.8
# side1-counter 3 : S1 6  S2 17
# side2-counter 4 : S3 6  S4 25
# side3-counter 4 : S5 13  S6 26
# side4-counter 4 : S7 6  S8 23
# Cycle Finished at 16 in com1
# Setting min-density to 1.5
# side1-counter 4 : S1 5  S2 23
# side2-counter 4 : S3 10  S4 14
# side3-counter 4 : S5 8  S6 14
# side4-counter 4 : S7 4  S8 23
# Cycle Finished at 32 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S5 7
# side2-counter 4 : S2 10  S6 11
# side3-counter 4 : S3 8  S7 7
# side4-counter 4 : S4 13  S8 13
# Cycle Finished at 48 in com6
# Setting min-density to 1.25
# side1-counter 4 : S1 6  S4 9
# side2-counter 4 : S2 11  S7 5
# side3-counter 4 : S3 14  S6 11
# side4-counter 4 : S5 7  S8 14
# Cycle Finished at 64 in com4
# Setting min-density to 1.25
# side1-counter 4 : S1 4  S5 3
# side2-counter 4 : S2 10  S6 12
# side3-counter 4 : S3 12  S7 7
# side4-counter 4 : S4 8  S8 14
# Cycle Finished at 80 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S2 4
# side2-counter 4 : S3 11  S7 6
# side3-counter 4 : S4 15  S8 11
# side4-counter 4 : S5 5  S6 11
# Cycle Finished at 96 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S2 10
# side2-counter 4 : S3 8  S4 8
# side3-counter 4 : S5 7  S6 10
# side4-counter 4 : S7 3  S8 10
# Cycle Finished at 112 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S2 10
# side2-counter 4 : S3 13  S4 12
# side3-counter 4 : S5 7  S6 10
# side4-counter 4 : S7 5  S8 11
# Cycle Finished at 128 in com1
# Setting min-density to 1.25
# side1-counter 4 : S1 6  S4 11
# side2-counter 4 : S2 10  S6 12
# side3-counter 4 : S3 12  S7 5
# side4-counter 4 : S5 8  S8 15
# Cycle Finished at 144 in com3
# Setting min-density to 1.25
# side1-counter 4 : S1 8  S2 14
# side2-counter 4 : S3 9  S4 10
# side3-counter 4 : S5 7  S6 11
# side4-counter 4 : S7 6  S8 12
# Cycle Finished at 160 in com1
# Setting min-density to 1.5
# side1-counter 4 : S1 6  S5 7
# side2-counter 4 : S2 10  S6 9
# side3-counter 4 : S3 11  S7 4
# side4-counter 4 : S4 11  S8 13
# Cycle Finished at 176 in com6
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S5 6
# side2-counter 4 : S2 12  S6 10
# side3-counter 4 : S3 10  S4 8
# side4-counter 4 : S7 6  S8 17
# Cycle Finished at 192 in com5
# Setting min-density to 1.25
# side1-counter 4 : S1 6  S2 12
# side2-counter 4 : S3 10  S4 9
# side3-counter 4 : S5 11  S6 11
# side4-counter 4 : S7 5  S8 9
# Cycle Finished at 208 in com1
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S5 6
# side2-counter 4 : S2 12  S6 13
# side3-counter 4 : S3 12  S4 10
# side4-counter 4 : S7 6  S8 15
# Cycle Finished at 224 in com5
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S2 12
# side2-counter 4 : S3 9  S4 8
# side3-counter 4 : S5 7  S6 11
# side4-counter 4 : S7 7  S8 11
# Cycle Finished at 240 in com1
# Setting min-density to 1.25
# side1-counter 3 : S1 2  S5 2
# side2-counter 4 : S2 24  S7 4
# side3-counter 4 : S3 4  S6 24
# side4-counter 4 : S4 26  S8 24
# Cycle Finished at 16 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S2 6
# side2-counter 4 : S3 6  S7 6
# side3-counter 4 : S4 16  S8 18
# side4-counter 4 : S5 2  S6 15
# Cycle Finished at 32 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 2
# side2-counter 4 : S2 15  S6 8
# side3-counter 4 : S3 3  S4 13
# side4-counter 4 : S7 2  S8 12
# Cycle Finished at 48 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 14
# side2-counter 4 : S2 10  S6 3
# side3-counter 4 : S3 6  S7 6
# side4-counter 4 : S5 2  S8 9
# Cycle Finished at 64 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S2 11
# side2-counter 4 : S3 6  S4 8
# side3-counter 4 : S5 1  S6 14
# side4-counter 4 : S7 6  S8 14
# Cycle Finished at 80 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 1
# side2-counter 4 : S2 15  S7 4
# side3-counter 4 : S3 5  S6 10
# side4-counter 4 : S4 13  S8 9
# Cycle Finished at 96 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 2
# side2-counter 4 : S2 10  S7 5
# side3-counter 4 : S3 5  S6 14
# side4-counter 4 : S4 11  S8 14
# Cycle Finished at 112 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 8
# side2-counter 4 : S3 5  S4 9
# side3-counter 4 : S5 2  S6 9
# side4-counter 4 : S7 11  S8 13
# Cycle Finished at 128 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 2
# side2-counter 4 : S2 10  S7 2
# side3-counter 4 : S3 6  S6 9
# side4-counter 4 : S4 12  S8 8
# Cycle Finished at 144 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 14
# side2-counter 4 : S2 15  S6 9
# side3-counter 4 : S3 5  S7 6
# side4-counter 4 : S5 1  S8 14
# Cycle Finished at 160 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 1
# side2-counter 4 : S2 8  S6 9
# side3-counter 4 : S3 6  S4 12
# side4-counter 4 : S7 1  S8 12
# Cycle Finished at 176 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 10
# side2-counter 4 : S3 7  S4 9
# side3-counter 4 : S5 2  S6 17
# side4-counter 4 : S7 6  S8 9
# Cycle Finished at 192 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 2
# side2-counter 4 : S2 12  S7 5
# side3-counter 4 : S3 4  S6 8
# side4-counter 4 : S4 10  S8 11
# Cycle Finished at 208 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 1
# side2-counter 4 : S2 8  S7 5
# side3-counter 4 : S3 5  S6 11
# side4-counter 4 : S4 12  S8 8
# Cycle Finished at 224 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S4 19
# side2-counter 4 : S2 14  S6 14
# side3-counter 4 : S3 5  S7 6
# side4-counter 4 : S5 2  S8 10
# Cycle Finished at 240 in com3
# Setting min-density to 0.8
# side1-counter 3 : S1 2  S5 6
# side2-counter 4 : S2 25  S7 5
# side3-counter 4 : S3 6  S6 24
# side4-counter 4 : S4 24  S8 25
# Cycle Finished at 16 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S2 4
# side2-counter 4 : S3 4  S7 5
# side3-counter 4 : S4 14  S8 27
# side4-counter 4 : S5 2  S6 12
# Cycle Finished at 32 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 4
# side2-counter 4 : S2 14  S6 16
# ...
# side4-counter 4 : S5 6  S6 15
# Cycle Finished at 160 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 1
# side2-counter 4 : S2 9  S6 14
# side3-counter 4 : S3 9  S7 5
# side4-counter 4 : S4 11  S8 13
# Cycle Finished at 176 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S4 14
# side2-counter 4 : S2 10  S7 6
# side3-counter 4 : S3 7  S6 11
# side4-counter 4 : S5 5  S8 14
# Cycle Finished at 192 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 3
# side2-counter 4 : S2 9  S6 8
# side3-counter 4 : S3 8  S4 9
# side4-counter 4 : S7 3  S8 14
# Cycle Finished at 208 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 5
# side2-counter 4 : S2 11  S6 10
# side3-counter 4 : S3 7  S4 9
# side4-counter 4 : S7 5  S8 11
# Cycle Finished at 224 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 9
# side2-counter 4 : S3 8  S4 13
# side3-counter 4 : S5 7  S6 12
# side4-counter 4 : S7 3  S8 16
# Cycle Finished at 240 in com1
# Setting min-density to 0.8
# side1-counter 3 : S1 4  S4 8
# side2-counter 4 : S2 25  S7 5
# side3-counter 4 : S3 6  S6 30
# side4-counter 4 : S5 2  S8 28
# Cycle Finished at 16 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 25
# side2-counter 4 : S2 10  S7 6
# side3-counter 4 : S3 7  S6 15
# side4-counter 4 : S5 1  S8 27
# Cycle Finished at 32 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 2
# side2-counter 4 : S2 7  S7 5
# side3-counter 4 : S3 5  S6 12
# side4-counter 4 : S4 11  S8 9
# Cycle Finished at 48 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S2 7
# side2-counter 4 : S3 5  S4 11
# side3-counter 4 : S5 2  S6 10
# side4-counter 4 : S7 6  S8 10
# Cycle Finished at 64 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 1
# side2-counter 4 : S2 13  S7 4
# side3-counter 4 : S3 5  S6 8
# side4-counter 4 : S4 10  S8 11
# Cycle Finished at 80 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 11  S2 8
# side2-counter 4 : S3 6  S7 4
# side3-counter 4 : S4 8  S8 14
# side4-counter 4 : S5 2  S6 13
# Cycle Finished at 96 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S2 11
# side2-counter 4 : S3 5  S4 7
# side3-counter 4 : S5 2  S6 10
# side4-counter 4 : S7 5  S8 16
# Cycle Finished at 112 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S4 11
# side2-counter 4 : S2 14  S6 9
# side3-counter 4 : S3 3  S7 4
# side4-counter 4 : S5 2  S8 11
# Cycle Finished at 128 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S2 9
# side2-counter 4 : S3 7  S4 9
# side3-counter 4 : S5 1  S6 12
# side4-counter 4 : S7 6  S8 12
# Cycle Finished at 144 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 10
# side2-counter 4 : S3 6  S7 5
# side3-counter 4 : S4 14  S8 11
# side4-counter 4 : S5 2  S6 11
# Cycle Finished at 160 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 8
# side2-counter 4 : S2 13  S7 4
# side3-counter 4 : S3 5  S6 11
# side4-counter 4 : S5 2  S8 12
# Cycle Finished at 176 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S2 7
# side2-counter 4 : S3 5  S7 7
# side3-counter 4 : S4 12  S8 9
# side4-counter 4 : S5 2  S6 10
# Cycle Finished at 192 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 2
# side2-counter 4 : S2 9  S7 5
# side3-counter 4 : S3 5  S6 12
# side4-counter 4 : S4 9  S8 7
# Cycle Finished at 208 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 2
# side2-counter 4 : S2 12  S7 5
# side3-counter 4 : S3 6  S6 11
# side4-counter 4 : S4 11  S8 10
# Cycle Finished at 224 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S4 19
# side2-counter 4 : S2 15  S7 5
# side3-counter 4 : S3 7  S6 11
# side4-counter 4 : S5 2  S8 9
# Cycle Finished at 240 in com4
# Setting min-density to 0.8
# side1-counter 3 : S1 4  S5 2
# side2-counter 4 : S2 21  S6 21
# side3-counter 4 : S3 12  S4 26
# side4-counter 4 : S7 2  S8 23
# Cycle Finished at 16 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 12
# side2-counter 4 : S3 7  S7 4
# side3-counter 4 : S4 15  S8 21
# side4-counter 4 : S5 4  S6 9
# Cycle Finished at 32 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S2 12
# side2-counter 4 : S3 8  S7 3
# side3-counter 4 : S4 15  S8 11
# side4-counter 4 : S5 7  S6 9
# Cycle Finished at 48 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S2 11
# side2-counter 4 : S3 13  S4 7
# side3-counter 4 : S5 4  S6 8
# side4-counter 4 : S7 5  S8 11
# Cycle Finished at 64 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 6  S5 4
# side2-counter 4 : S2 6  S6 13
# side3-counter 4 : S3 8  S7 4
# side4-counter 4 : S4 12  S8 13
# Cycle Finished at 80 in com6
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S4 10
# side2-counter 4 : S2 9  S6 15
# side3-counter 4 : S3 10  S7 3
# side4-counter 4 : S5 2  S8 8
# Cycle Finished at 96 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S2 11
# side2-counter 4 : S3 9  S7 3
# side3-counter 4 : S4 10  S8 11
# side4-counter 4 : S5 4  S6 14
# Cycle Finished at 112 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S4 2
# side2-counter 4 : S2 15  S7 3
# side3-counter 4 : S3 16  S6 13
# side4-counter 4 : S5 4  S8 11
# Cycle Finished at 128 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S4 13
# side2-counter 4 : S2 9  S7 4
# side3-counter 4 : S3 9  S6 13
# side4-counter 4 : S5 2  S8 11
# Cycle Finished at 144 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 4
# side2-counter 4 : S2 6  S7 3
# side3-counter 4 : S3 7  S6 9
# side4-counter 4 : S4 9  S8 14
# Cycle Finished at 160 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 4
# side2-counter 4 : S2 14  S6 12
# side3-counter 4 : S3 10  S4 11
# side4-counter 4 : S7 4  S8 12
# Cycle Finished at 176 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 4
# side2-counter 4 : S2 12  S6 13
# side3-counter 4 : S3 9  S4 16
# side4-counter 4 : S7 4  S8 11
# Cycle Finished at 192 in com5
# Setting min-density to 1.0
# side1-counter 4 : S1 6  S2 17
# side2-counter 4 : S3 9  S4 14
# side3-counter 4 : S5 4  S6 8
# side4-counter 4 : S7 3  S8 9
# Cycle Finished at 208 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S2 8
# side2-counter 4 : S3 8  S4 10
# side3-counter 4 : S5 4  S6 18
# side4-counter 4 : S7 3  S8 16
# Cycle Finished at 224 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S5 4
# side2-counter 4 : S2 13  S7 4
# side3-counter 4 : S3 9  S6 10
# side4-counter 4 : S4 14  S8 13
# Cycle Finished at 240 in com7
# Setting min-density to 1.0
# side1-counter 3 : S1 7  S5 6
# side2-counter 4 : S2 22  S7 0
# side3-counter 4 : S3 5  S6 23
# side4-counter 4 : S4 26  S8 25
# Cycle Finished at 16 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S2 6
# side2-counter 4 : S3 7  S4 18
# side3-counter 4 : S5 5  S6 12
# side4-counter 4 : S7 3  S8 17
# Cycle Finished at 32 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 12  S2 11
# side2-counter 4 : S3 7  S7 1
# side3-counter 4 : S4 10  S8 10
# side4-counter 4 : S5 6  S6 8
# Cycle Finished at 48 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 3
# side2-counter 4 : S2 15  S7 4
# side3-counter 4 : S3 6  S6 10
# side4-counter 4 : S4 10  S8 11
# Cycle Finished at 64 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S5 6
# side2-counter 4 : S2 13  S7 4
# side3-counter 4 : S3 9  S6 9
# side4-counter 4 : S4 10  S8 11
# Cycle Finished at 80 in com7
# Setting min-density to 1.0
# side1-counter 4 : S1 10  S5 8
# side2-counter 4 : S2 10  S6 14
# side3-counter 4 : S3 8  S4 10
# side4-counter 4 : S7 8  S8 12
# Cycle Finished at 96 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 3
# side2-counter 4 : S2 13  S6 9
# side3-counter 4 : S3 7  S4 9
# side4-counter 4 : S7 3  S8 10
# Cycle Finished at 112 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S2 13
# side2-counter 4 : S3 8  S7 3
# side3-counter 4 : S4 14  S8 9
# side4-counter 4 : S5 7  S6 10
# Cycle Finished at 128 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S5 2
# side2-counter 4 : S2 12  S6 10
# side3-counter 4 : S3 8  S7 4
# side4-counter 4 : S4 14  S8 10
# Cycle Finished at 144 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S2 10
# side2-counter 4 : S3 10  S7 4
# side3-counter 4 : S4 11  S8 8
# side4-counter 4 : S5 11  S6 11
# Cycle Finished at 160 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S5 3
# side2-counter 4 : S2 16  S6 13
# side3-counter 4 : S3 7  S4 7
# side4-counter 4 : S7 4  S8 14
# Cycle Finished at 176 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 12  S2 10
# side2-counter 4 : S3 8  S7 4
# side3-counter 4 : S4 9  S8 17
# side4-counter 4 : S5 9  S6 16
# Cycle Finished at 192 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 8  S5 3
# side2-counter 4 : S2 9  S6 13
# side3-counter 4 : S3 8  S4 14
# side4-counter 4 : S7 3  S8 10
# Cycle Finished at 208 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 9  S5 6
# side2-counter 4 : S2 9  S6 12
# side3-counter 4 : S3 6  S4 15
# side4-counter 4 : S7 6  S8 10
# Cycle Finished at 224 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 4
# side2-counter 4 : S2 9  S6 11
# side3-counter 4 : S3 10  S7 3
# side4-counter 4 : S4 9  S8 10
# Cycle Finished at 240 in com6
# Setting min-density to 0.8
# side1-counter 3 : S1 0  S2 20
# side2-counter 4 : S3 0  S4 28
# side3-counter 4 : S5 3  S6 29
# side4-counter 4 : S7 12  S8 27
# Cycle Finished at 16 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S2 15
# side2-counter 4 : S3 3  S4 14
# side3-counter 4 : S5 4  S6 15
# side4-counter 4 : S7 10  S8 21
# Cycle Finished at 32 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S4 9
# side2-counter 4 : S2 11  S6 9
# side3-counter 4 : S3 3  S7 10
# side4-counter 4 : S5 4  S8 15
# Cycle Finished at 48 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 2
# side2-counter 4 : S2 14  S6 13
# side3-counter 4 : S3 5  S7 10
# side4-counter 4 : S4 8  S8 13
# Cycle Finished at 64 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S4 10
# side2-counter 4 : S2 8  S7 9
# side3-counter 4 : S3 4  S6 13
# side4-counter 4 : S5 4  S8 17
# Cycle Finished at 80 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S4 5
# side2-counter 4 : S2 15  S6 10
# side3-counter 4 : S3 4  S7 6
# side4-counter 4 : S5 4  S8 11
# Cycle Finished at 96 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S4 9
# side2-counter 4 : S2 7  S7 10
# side3-counter 4 : S3 7  S6 11
# side4-counter 4 : S5 2  S8 10
# Cycle Finished at 112 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S4 8
# side2-counter 4 : S2 12  S7 10
# side3-counter 4 : S3 5  S6 12
# side4-counter 4 : S5 4  S8 11
# Cycle Finished at 128 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S4 9
# side2-counter 4 : S2 10  S7 9
# side3-counter 4 : S3 4  S6 11
# side4-counter 4 : S5 4  S8 9
# Cycle Finished at 144 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S4 12
# side2-counter 4 : S2 11  S7 9
# side3-counter 4 : S3 4  S6 13
# side4-counter 4 : S5 2  S8 16
# Cycle Finished at 160 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S2 6
# side2-counter 4 : S3 3  S7 10
# side3-counter 4 : S4 17  S8 9
# side4-counter 4 : S5 4  S6 13
# Cycle Finished at 176 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 3
# side2-counter 4 : S2 12  S6 14
# side3-counter 4 : S3 4  S7 11
# side4-counter 4 : S4 13  S8 8
# Cycle Finished at 192 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S2 4
# side2-counter 4 : S3 4  S4 14
# side3-counter 4 : S5 3  S6 14
# side4-counter 4 : S7 9  S8 8
# Cycle Finished at 208 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S4 11
# side2-counter 4 : S2 11  S6 11
# side3-counter 4 : S3 2  S7 10
# side4-counter 4 : S5 3  S8 11
# Cycle Finished at 224 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 4
# side2-counter 4 : S2 11  S6 10
# side3-counter 4 : S3 3  S4 14
# side4-counter 4 : S7 4  S8 12
# Cycle Finished at 240 in com5
# Setting min-density to 0.8
# side1-counter 3 : S1 4  S2 13
# side2-counter 4 : S3 2  S4 23
# side3-counter 4 : S5 5  S6 26
# side4-counter 4 : S7 4  S8 29
# Cycle Finished at 16 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 6
# side2-counter 4 : S2 15  S6 13
# side3-counter 4 : S3 4  S7 2
# side4-counter 4 : S4 19  S8 20
# Cycle Finished at 32 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S4 13
# side2-counter 4 : S2 12  S6 8
# side3-counter 4 : S3 3  S7 4
# side4-counter 4 : S5 6  S8 17
# Cycle Finished at 48 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 0
# side2-counter 4 : S2 10  S7 2
# side3-counter 4 : S3 4  S6 11
# side4-counter 4 : S4 12  S8 9
# Cycle Finished at 64 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 4
# side2-counter 4 : S3 2  S4 10
# side3-counter 4 : S5 6  S6 16
# side4-counter 4 : S7 7  S8 7
# Cycle Finished at 80 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 6
# side2-counter 4 : S2 10  S6 15
# side3-counter 4 : S3 4  S4 11
# side4-counter 4 : S7 6  S8 18
# Cycle Finished at 96 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 4
# side2-counter 4 : S2 13  S7 3
# side3-counter 4 : S3 4  S6 12
# side4-counter 4 : S4 10  S8 13
# Cycle Finished at 112 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 10
# side2-counter 4 : S3 3  S4 11
# side3-counter 4 : S5 5  S6 11
# side4-counter 4 : S7 4  S8 13
# Cycle Finished at 128 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 5
# side2-counter 4 : S2 14  S6 10
# side3-counter 4 : S3 3  S7 3
# side4-counter 4 : S4 10  S8 13
# Cycle Finished at 144 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 7
# side2-counter 4 : S2 10  S7 3
# side3-counter 4 : S3 4  S6 14
# side4-counter 4 : S4 9  S8 19
# Cycle Finished at 160 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 6
# side2-counter 4 : S2 13  S6 11
# side3-counter 4 : S3 5  S7 4
# side4-counter 4 : S4 15  S8 9
# Cycle Finished at 176 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 5
# side2-counter 4 : S2 12  S6 14
# side3-counter 4 : S3 6  S4 10
# side4-counter 4 : S7 5  S8 13
# Cycle Finished at 192 in com5
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S5 5
# side2-counter 4 : S2 13  S6 13
# side3-counter 4 : S3 4  S4 9
# side4-counter 4 : S7 5  S8 8
# Cycle Finished at 208 in com5
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S2 15
# side2-counter 4 : S3 4  S7 3
# side3-counter 4 : S4 11  S8 9
# side4-counter 4 : S5 6  S6 17
# Cycle Finished at 224 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 5
# side2-counter 4 : S2 10  S6 13
# side3-counter 4 : S3 3  S7 3
# side4-counter 4 : S4 9  S8 11
# Cycle Finished at 240 in com6
# Setting min-density to 0.8
# side1-counter 3 : S1 8  S4 7
# side2-counter 4 : S2 21  S6 19
# side3-counter 4 : S3 8  S7 10
# side4-counter 4 : S5 4  S8 29
# Cycle Finished at 16 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S5 5
# side2-counter 4 : S2 11  S6 8
# side3-counter 4 : S3 5  S4 15
# side4-counter 4 : S7 5  S8 17
# Cycle Finished at 32 in com5
# Setting min-density to 1.25
# side1-counter 4 : S1 4  S4 14
# side2-counter 4 : S2 11  S6 8
# side3-counter 4 : S3 6  S7 6
# side4-counter 4 : S5 6  S8 11
# Cycle Finished at 48 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 6  S2 9
# side2-counter 4 : S3 8  S4 9
# side3-counter 4 : S5 10  S6 12
# side4-counter 4 : S7 17  S8 13
# Cycle Finished at 64 in com1
# Setting min-density to 1.5
# side1-counter 4 : S1 7  S4 16
# side2-counter 4 : S2 11  S6 10
# side3-counter 4 : S3 9  S7 10
# side4-counter 4 : S5 5  S8 11
# Cycle Finished at 80 in com3
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S5 4
# side2-counter 4 : S2 8  S6 16
# side3-counter 4 : S3 8  S7 8
# side4-counter 4 : S4 10  S8 11
# Cycle Finished at 96 in com6
# Setting min-density to 1.0
# side1-counter 4 : S1 8  S5 7
# side2-counter 4 : S2 12  S6 10
# side3-counter 4 : S3 6  S4 9
# side4-counter 4 : S7 7  S8 9
# Cycle Finished at 112 in com5
# Setting min-density to 1.5
# side1-counter 4 : S1 6  S5 4
# side2-counter 4 : S2 9  S7 6
# side3-counter 4 : S3 7  S6 17
# side4-counter 4 : S4 11  S8 15
# Cycle Finished at 128 in com7
# Setting min-density to 1.0
# side1-counter 4 : S1 7  S2 9
# side2-counter 4 : S3 8  S4 13
# side3-counter 4 : S5 6  S6 8
# side4-counter 4 : S7 4  S8 11
# Cycle Finished at 144 in com1
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S5 6
# side2-counter 4 : S2 13  S6 9
# side3-counter 4 : S3 7  S4 17
# side4-counter 4 : S7 6  S8 11
# Cycle Finished at 160 in com5
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S5 7
# side2-counter 4 : S2 11  S7 4

# %%
env.close()

# %% [markdown]
# ### PPO Testing

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
import numpy as np

# Initialize the environment
env = TrafficSimulation()
env = Monitor(env)  # Wrapping the environment for logging

# Define the path where your PPO model is saved
model_save_path = os.path.join('Training', 'PPO_Traffic_Model')

# Load the saved model
model = PPO.load(model_save_path, env=env)

# Reset the environment to start a new episode
observation, _ = env.reset()

# Initialize variables to keep track of cumulative reward
cumulative_reward = 0
num_steps = 100  # Number of steps you want to run the simulation

for step in range(num_steps):
    # Predict the action to take based on the current observation
    action, _ = model.predict(observation, deterministic=True)
    
    # Take the action in the environment
    observation, reward, done, truncated, info = env.step(action)
    
    # Accumulate the reward
    cumulative_reward += reward

    # Print the results for each step
    print(f"Step {step + 1}:")
    print(f"Action Taken: {action}")
    print(f"Observation: {observation}")
    print(f"Reward: {reward}")
    print(f"Cumulative Reward: {cumulative_reward}")
    print("-" * 30)
    
    # If the episode is done, reset the environment and print the cumulative reward
    if done or truncated:
        print(f"Episode finished. Cumulative Reward: {cumulative_reward}")
        # Reset the environment and cumulative reward for the next episode
        observation, _ = env.reset()
        cumulative_reward = 0

# Close the environment after the simulation
env.close()
# Out:
# C:\Users\LENOVO\AppData\Roaming\Python\Python312\site-packages\stable_baselines3\common\save_util.py:167: UserWarning: Could not deserialize object clip_range. Consider using `custom_objects` argument to replace this object.
# Exception: Can't get attribute '_function_setstate' on <module 'cloudpickle.cloudpickle' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\cloudpickle\\cloudpickle.py'>
#   warnings.warn(
# C:\Users\LENOVO\AppData\Roaming\Python\Python312\site-packages\stable_baselines3\common\save_util.py:167: UserWarning: Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: Can't get attribute '_function_setstate' on <module 'cloudpickle.cloudpickle' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\cloudpickle\\cloudpickle.py'>
#   warnings.warn(
# Wrapping the env in a DummyVecEnv.
# Setting min-density to 0.8
# Step 1:
# Action Taken: [ 3 19  0 17  7]
# Observation: [0.75 6.4  0.6  3.   2.   6.4  1.   7.  ]
# Reward: -1
# Cumulative Reward: -1
# ------------------------------
# Setting min-density to 0.8
# Step 2:
# Action Taken: [ 3 27  0 17  7]
# Observation: [1.  4.  1.  3.8 2.2 3.  0.6 4.6]
# Reward: 1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 3:
# Action Taken: [ 0 12 20 17 14]
# Observation: [1.2 1.4 1.  3.2 2.  2.8 0.8 2.4]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 4:
# Action Taken: [ 0 14 17  0 20]
# Observation: [2.6 2.8 1.2 2.8 2.  3.6 0.4 2.8]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 5:
# Action Taken: [ 0 14  7 17 29]
# Observation: [1.2 2.6 0.8 2.8 1.8 2.6 0.6 2.8]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 6:
# Action Taken: [ 0 12 17 17 14]
# Observation: [1.  3.4 1.2 2.8 0.8 2.4 0.6 3.8]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 7:
# Action Taken: [ 6 12 35  7 14]
# Observation: [1.2 1.8 1.2 2.8 1.2 2.  0.8 3.4]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 8:
# Action Taken: [ 0 12 17  4 20]
# Observation: [1.2 2.  0.8 2.2 2.2 2.4 0.8 2.8]
# Reward: 1
# Cumulative Reward: 2
# ------------------------------
# Setting min-density to 0.8
# Step 9:
# Action Taken: [ 4 12 17  0 20]
# Observation: [0.8 3.  2.4 2.4 1.2 2.8 0.8 2.8]
# Reward: -1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 10:
# Action Taken: [ 6 24 17 17 17]
# Observation: [1.4 2.6 1.4 3.6 1.4 3.6 0.8 3.4]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 11:
# Action Taken: [ 0 14  7 17 20]
# Observation: [0.8 2.2 1.2 2.4 3.  2.4 0.6 2.2]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 12:
# Action Taken: [ 1 12 17  0 34]
# Observation: [1.  2.2 1.2 3.  2.  2.8 0.6 2.6]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 13:
# Action Taken: [ 0 14 17 17 20]
# Observation: [1.2 2.4 1.4 3.4 2.2 3.  0.6 4.4]
# Reward: -1
# Cumulative Reward: -1
# ------------------------------
# Setting min-density to 0.8
# Step 14:
# Action Taken: [ 4 12 17  4 14]
# Observation: [1.4 2.8 0.8 4.  1.6 2.6 0.6 2.8]
# Reward: 1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 15:
# Action Taken: [ 0 14 17  2 14]
# Observation: [1.  2.6 1.  2.  2.4 3.  0.6 3.8]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Episode finished. Cumulative Reward: 1
# Setting min-density to 0.8
# Step 16:
# Action Taken: [ 3 19  0 17  7]
# Observation: [2.25 6.   0.8  6.5  2.4  6.6  0.4  5.8 ]
# Reward: -1
# Cumulative Reward: -1
# ------------------------------
# Setting min-density to 0.8
# Step 17:
# Action Taken: [ 0  7 35 17  9]
# Observation: [1.4 3.  1.2 3.6 1.2 3.2 0.2 3.2]
# Reward: 1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 18:
# Action Taken: [ 0 14 35 17 20]
# Observation: [1.2 3.2 1.  3.6 1.6 3.2 0.2 2.8]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 19:
# Action Taken: [ 0 14 35 17 14]
# Observation: [1.4 2.6 1.  4.4 0.6 2.6 0.4 3.2]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 20:
# Action Taken: [ 0 33 35  2 20]
# Observation: [1.4 3.  1.  3.4 2.4 2.8 0.2 3.2]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 21:
# Action Taken: [ 0 14 17 17 14]
# Observation: [1.2 3.6 1.2 3.8 0.8 3.  0.4 2.4]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 22:
# Action Taken: [ 0 28 35 30  9]
# Observation: [0.8 2.8 0.  2.4 1.8 4.2 0.4 4.4]
# Reward: -1
# Cumulative Reward: -1
# ------------------------------
# Setting min-density to 0.8
# Step 23:
# Action Taken: [ 3 12  0 17  7]
# Observation: [1.4 3.4 1.2 3.4 1.2 2.8 0.4 2.6]
# Reward: 1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 24:
# Action Taken: [ 0 14 35 17  9]
# Observation: [1.6 3.8 0.  3.  1.2 4.2 0.4 2.8]
# Reward: -1
# Cumulative Reward: -1
# ------------------------------
# Setting min-density to 0.8
# Step 25:
# Action Taken: [ 0  7 24 17 12]
# Observation: [1.4 3.2 1.2 3.  1.4 1.8 0.2 3. ]
# Reward: 1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 26:
# Action Taken: [ 0 24 35  2 14]
# Observation: [1.2 2.2 0.2 3.8 1.8 2.4 0.4 2.8]
# Reward: -1
# Cumulative Reward: -1
# ------------------------------
# Setting min-density to 0.8
# Step 27:
# Action Taken: [ 0 12 20  2 20]
# Observation: [1.  3.4 0.8 3.2 1.4 3.2 0.4 2.4]
# Reward: 1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 28:
# Action Taken: [ 0  1 35 17 21]
# Observation: [1.4 2.  0.4 2.  1.  2.2 0.4 3.6]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 29:
# Action Taken: [ 4 22  7  7 33]
# Observation: [1.4 2.6 0.8 3.  1.6 2.6 0.2 3.2]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 30:
# Action Taken: [ 0 12  7 17 14]
# Observation: [1.2 3.8 0.  3.8 2.8 3.2 0.2 3.4]
# Reward: -1
# Cumulative Reward: -1
# ------------------------------
# Episode finished. Cumulative Reward: -1
# Setting min-density to 1.2
# Step 31:
# Action Taken: [ 3 19  0 17  7]
# Observation: [1.5  6.   1.4  2.75 1.2  6.   1.2  7.  ]
# Reward: -1
# Cumulative Reward: -1
# ------------------------------
# Setting min-density to 0.8
# Step 32:
# Action Taken: [ 5 27  0 17 10]
# Observation: [1.4 2.6 1.4 4.2 1.2 2.4 0.6 3.2]
# Reward: 1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 33:
# Action Taken: [ 0 24 17  2 20]
# Observation: [1.4 1.8 1.2 2.  1.6 2.2 0.6 2.4]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 34:
# Action Taken: [ 0 14  7  4 20]
# Observation: [1.8 2.  1.6 3.4 1.8 3.8 0.6 2.8]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 35:
# Action Taken: [ 0 14  7  4 20]
# Observation: [1.4 2.2 1.4 3.  1.8 2.4 0.6 2.4]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 36:
# Action Taken: [ 0 14 17  2 20]
# Observation: [0.8 3.  1.2 3.2 1.8 2.4 0.6 2. ]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 37:
# Action Taken: [ 0 14 17  2 19]
# Observation: [1.2 3.4 1.4 2.6 2.  1.8 0.6 2. ]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 38:
# Action Taken: [ 0 14 17  2 19]
# Observation: [1.2 2.8 1.4 3.4 1.8 2.8 0.6 3. ]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 39:
# Action Taken: [ 0 14 17  2 14]
# Observation: [1.8 2.4 1.2 3.2 2.  2.2 0.6 2.6]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 40:
# Action Taken: [ 0 14 17  2 14]
# Observation: [1.4 3.2 2.  3.2 2.  2.8 0.8 2.8]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 41:
# Action Taken: [ 0 14 17  2 19]
# Observation: [1.4 2.4 1.4 2.2 2.  3.  0.8 3. ]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 42:
# Action Taken: [ 4 14 11 17 20]
# Observation: [1.2 3.4 1.4 4.2 1.  2.6 0.8 3.8]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 43:
# Action Taken: [ 0 12 35  2 14]
# Observation: [1.2 3.  1.6 3.4 2.4 2.6 0.8 4. ]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 44:
# Action Taken: [ 0 12 17  0 14]
# Observation: [1.4 3.  3.  3.6 1.8 3.6 0.8 2.6]
# Reward: 1
# Cumulative Reward: 2
# ------------------------------
# Setting min-density to 0.8
# Step 45:
# Action Taken: [ 6 14 17  4 31]
# Observation: [2.  3.  1.4 3.4 1.6 2.6 0.6 2.6]
# Reward: 1
# Cumulative Reward: 3
# ------------------------------
# Episode finished. Cumulative Reward: 3
# Setting min-density to 1.0
# Step 46:
# Action Taken: [ 3 19  0 17  7]
# Observation: [1.75 6.2  1.2  5.   1.4  6.6  1.   6.6 ]
# Reward: -1
# Cumulative Reward: -1
# ------------------------------
# Setting min-density to 0.8
# Step 47:
# Action Taken: [ 6 28 35 17 21]
# Observation: [1.6 3.4 1.2 4.4 0.2 3.  1.2 3.4]
# Reward: 1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 48:
# Action Taken: [ 0 33 24  7  9]
# Observation: [2.4 1.4 0.6 3.8 0.8 2.6 1.  3. ]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 49:
# Action Taken: [ 0 29  7 34 33]
# Observation: [1.6 2.8 1.2 4.2 0.8 2.8 0.8 4.4]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 0.8
# Step 50:
# Action Taken: [ 0 33  7  7 33]
# Observation: [1.4 2.8 1.2 3.  0.8 3.4 1.  2.2]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 51:
# Action Taken: [ 0 14  8 17 20]
# Observation: [2.  3.2 1.  3.2 1.  4.  0.8 2.8]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 1.0
# Step 52:
# Action Taken: [ 0  7  7 17 20]
# Observation: [1.8 2.6 1.2 3.2 1.2 2.4 1.  3.4]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 53:
# Action Taken: [ 0  3  7  2 20]
# Observation: [2.6 2.8 1.  3.2 0.8 2.  1.2 2.6]
# Reward: 1
# Cumulative Reward: 2
# ------------------------------
# Setting min-density to 0.8
# Step 54:
# Action Taken: [ 0  3  7  2 29]
# Observation: [2.  3.4 1.2 2.4 0.8 3.6 1.4 2. ]
# Reward: -1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 0.8
# Step 55:
# Action Taken: [ 0  7  8  9 29]
# Observation: [1.8 2.6 1.2 2.6 0.8 2.6 1.  2.4]
# Reward: 1
# Cumulative Reward: 2
# ------------------------------
# Setting min-density to 0.8
# Step 56:
# Action Taken: [ 0 24  7  7 29]
# Observation: [1.2 2.4 1.  2.8 1.2 2.8 0.8 2.8]
# Reward: -1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 1.0
# Step 57:
# Action Taken: [ 0 14  7 17 20]
# Observation: [1.6 2.6 1.  3.4 1.  2.4 1.2 2.8]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 1.0
# Step 58:
# Action Taken: [ 0  3  7  2 20]
# Observation: [1.4 2.6 1.  3.2 1.  2.8 1.  2.6]
# Reward: -1
# Cumulative Reward: -1
# ------------------------------
# Setting min-density to 0.8
# Step 59:
# Action Taken: [ 0 14  7  2 20]
# Observation: [1.6 3.4 0.8 2.2 0.8 3.2 1.2 2. ]
# Reward: -1
# Cumulative Reward: -2
# ------------------------------
# Setting min-density to 1.0
# Step 60:
# Action Taken: [ 0  1  8  9 29]
# Observation: [2.  2.6 1.  2.2 1.  2.6 1.2 2.8]
# Reward: 1
# Cumulative Reward: -1
# ------------------------------
# Episode finished. Cumulative Reward: -1
# Setting min-density to 1.2
# Step 61:
# Action Taken: [ 3 19  0 17  7]
# Observation: [2.25 6.2  1.6  3.25 1.2  6.6  1.8  6.4 ]
# Reward: -1
# Cumulative Reward: -1
# ------------------------------
# Setting min-density to 1.2
# Step 62:
# Action Taken: [ 4 28  8  7 11]
# Observation: [1.8 2.4 1.4 4.8 1.2 4.4 2.6 3.4]
# Reward: 1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 1.8
# Step 63:
# Action Taken: [ 0 14  9 29 20]
# Observation: [1.8 2.8 2.  2.2 1.8 2.2 2.8 2. ]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 1.4
# Step 64:
# Action Taken: [ 0 15  3  0 15]
# Observation: [2.2 2.6 1.4 3.4 1.8 3.4 2.4 2. ]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 1.2
# Step 65:
# Action Taken: [ 0 14 32  2 29]
# Observation: [2.6 3.8 1.4 3.2 1.2 2.4 2.2 2.8]
# Reward: -1
# Cumulative Reward: -1
# ------------------------------
# Setting min-density to 1.6
# Step 66:
# Action Taken: [ 0 19  8  2 29]
# Observation: [1.6 2.6 1.6 3.  1.8 2.8 2.8 2.4]
# Reward: 1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 1.4
# Step 67:
# Action Taken: [ 0 15  3  0 15]
# Observation: [1.4 2.6 1.6 3.2 1.6 2.6 3.2 1.8]
# Reward: -1
# Cumulative Reward: -1
# ------------------------------
# Setting min-density to 1.4
# Step 68:
# Action Taken: [ 0  2  3  0 15]
# Observation: [2.  3.2 1.4 3.  1.4 3.2 3.  3. ]
# Reward: -1
# Cumulative Reward: -2
# ------------------------------
# Setting min-density to 1.4
# Step 69:
# Action Taken: [ 0 19  3  0 29]
# Observation: [1.4 2.8 2.6 2.  1.6 3.4 4.  3.4]
# Reward: -1
# Cumulative Reward: -3
# ------------------------------
# Setting min-density to 1.6
# Step 70:
# Action Taken: [ 4  8 31  0 15]
# Observation: [2.  3.2 1.6 3.6 2.  3.  2.4 3.6]
# Reward: 1
# Cumulative Reward: -2
# ------------------------------
# Setting min-density to 1.4
# Step 71:
# Action Taken: [ 0  3 17  0 29]
# Observation: [1.4 4.  1.6 1.8 2.  2.8 2.4 3. ]
# Reward: -1
# Cumulative Reward: -3
# ------------------------------
# Setting min-density to 1.4
# Step 72:
# Action Taken: [ 4  1 11  0 19]
# Observation: [2.2 2.4 1.6 3.4 1.4 2.2 2.2 2.8]
# Reward: 1
# Cumulative Reward: -2
# ------------------------------
# Setting min-density to 1.4
# Step 73:
# Action Taken: [ 0  3  7  2 29]
# Observation: [2.  2.6 1.4 3.  2.4 3.8 2.6 3.4]
# Reward: -1
# Cumulative Reward: -3
# ------------------------------
# Setting min-density to 1.2
# Step 74:
# Action Taken: [ 4 14 31  0 13]
# Observation: [1.6 2.2 1.2 2.4 1.8 3.6 2.2 2.8]
# Reward: 1
# Cumulative Reward: -2
# ------------------------------
# Setting min-density to 1.0
# Step 75:
# Action Taken: [ 4 14 31  0 13]
# Observation: [1.6 2.8 1.  3.4 1.6 3.  2.  3.2]
# Reward: -1
# Cumulative Reward: -3
# ------------------------------
# Episode finished. Cumulative Reward: -3
# Setting min-density to 1.4
# Step 76:
# Action Taken: [ 3 19  0 17  7]
# Observation: [2.75 6.   1.4  4.5  2.2  6.2  1.8  6.  ]
# Reward: -1
# Cumulative Reward: -1
# ------------------------------
# Setting min-density to 1.2
# Step 77:
# Action Taken: [ 0  1 24 17  7]
# Observation: [2.2 1.8 1.4 4.4 1.4 3.6 1.2 2.2]
# Reward: 1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 1.4
# Step 78:
# Action Taken: [ 0 14  7  2 20]
# Observation: [2.4 3.4 1.4 2.8 2.  3.  3.2 3.4]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 1.4
# Step 79:
# Action Taken: [ 4  3  3  0 29]
# Observation: [2.2 4.2 1.6 3.8 2.2 3.6 1.4 2.4]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 1.8
# Step 80:
# Action Taken: [ 0 14  8  2 29]
# Observation: [2.2 4.8 1.8 3.4 2.2 2.8 1.8 2. ]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 1.4
# Step 81:
# Action Taken: [ 0 14  8  2 19]
# Observation: [3.  3.  3.6 3.2 1.4 3.8 2.  4.2]
# Reward: 1
# Cumulative Reward: 2
# ------------------------------
# Setting min-density to 1.6
# Step 82:
# Action Taken: [ 0 24  7  7  3]
# Observation: [2.2 3.4 1.6 3.8 1.8 3.2 2.  4. ]
# Reward: -1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 1.6
# Step 83:
# Action Taken: [ 0  3  7  2 29]
# Observation: [2.2 2.4 2.4 2.6 2.  2.4 1.6 3. ]
# Reward: 1
# Cumulative Reward: 2
# ------------------------------
# Setting min-density to 1.6
# Step 84:
# Action Taken: [ 0 14 17 20 29]
# Observation: [1.6 3.  2.2 2.6 1.8 3.8 1.6 4.2]
# Reward: -1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 1.2
# Step 85:
# Action Taken: [ 4 24 17  4 20]
# Observation: [2.4 3.4 1.2 3.8 1.4 3.  1.8 3. ]
# Reward: 1
# Cumulative Reward: 2
# ------------------------------
# Setting min-density to 1.6
# Step 86:
# Action Taken: [ 0  3  7  2 29]
# Observation: [2.2 4.2 1.6 3.  2.  3.6 2.  2. ]
# Reward: 1
# Cumulative Reward: 3
# ------------------------------
# Setting min-density to 1.2
# Step 87:
# Action Taken: [ 0 14  8  2 29]
# Observation: [3.2 3.6 1.2 2.6 2.2 1.6 1.6 2.8]
# Reward: 1
# Cumulative Reward: 4
# ------------------------------
# Setting min-density to 1.4
# Step 88:
# Action Taken: [ 0 15  7 20 29]
# Observation: [1.6 4.  1.4 3.6 2.4 4.4 1.6 3. ]
# Reward: -1
# Cumulative Reward: 3
# ------------------------------
# Setting min-density to 1.2
# Step 89:
# Action Taken: [ 0 14 23 17 13]
# Observation: [2.  3.  1.2 2.6 2.  2.8 2.  2.2]
# Reward: 1
# Cumulative Reward: 4
# ------------------------------
# Setting min-density to 1.6
# Step 90:
# Action Taken: [ 0 14 23  0 29]
# Observation: [1.6 2.2 1.6 2.4 1.6 3.2 2.  2.2]
# Reward: 1
# Cumulative Reward: 5
# ------------------------------
# Episode finished. Cumulative Reward: 5
# Setting min-density to 1.5
# Step 91:
# Action Taken: [ 3 19  0 17  7]
# Observation: [1.5 6.6 2.6 2.  2.  6.2 2.8 7. ]
# Reward: -1
# Cumulative Reward: -1
# ------------------------------
# Setting min-density to 0.8
# Step 92:
# Action Taken: [ 5 27 26 17  2]
# Observation: [1.8 0.8 2.2 4.8 1.6 3.2 3.  3.8]
# Reward: 1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 1.4
# Step 93:
# Action Taken: [ 0  3  9 29 20]
# Observation: [3.2 1.4 2.6 3.8 2.  4.  3.6 3.4]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 2.2
# Step 94:
# Action Taken: [ 4 14  7 29 29]
# Observation: [2.2 3.8 2.6 3.  2.2 2.8 2.2 2.2]
# Reward: 1
# Cumulative Reward: 2
# ------------------------------
# Setting min-density to 1.8
# Step 95:
# Action Taken: [ 0 14 17  2 19]
# Observation: [1.8 2.8 2.6 3.  4.  2.4 3.  2.4]
# Reward: -1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 2.0
# Step 96:
# Action Taken: [ 4 15 17  0 19]
# Observation: [2.  2.6 2.4 4.  2.  3.2 2.6 2.6]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 1.6
# Step 97:
# Action Taken: [ 0 14 17  2 29]
# Observation: [2.2 3.2 3.  3.  1.6 3.2 2.8 2.4]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 1.4
# Step 98:
# Action Taken: [ 0 14 17  2 15]
# Observation: [1.4 3.4 1.6 4.6 2.  3.6 2.8 3. ]
# Reward: -1
# Cumulative Reward: 0
# ------------------------------
# Setting min-density to 1.8
# Step 99:
# Action Taken: [ 0  2  3  0 13]
# Observation: [2.  3.  3.  2.4 1.8 4.  4.  3.2]
# Reward: 1
# Cumulative Reward: 1
# ------------------------------
# Setting min-density to 1.8
# Step 100:
# Action Taken: [ 4  8 31  0 15]
# Observation: [1.8 3.2 2.4 2.8 2.  2.4 2.  2.6]
# Reward: 1
# Cumulative Reward: 2
# ------------------------------

# %%
# Save the model to the specified path
model.save(model_save_path)

# %%
del model

# %%
env.close()

# %%
import os
from stable_baselines3 import A2C
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env

# %%
# Assuming TrafficSimulation is your custom environment class
# You should have it implemented similarly to how you've set up for PPO

# Create the environment
env = TrafficSimulation()

# %%
# Define the path for logs and save the model
log_path = os.path.join('Training', 'Logs')
model_save_path = os.path.join('Training', 'A2C_Traffic_Model')

# Create the DQN model with an MLP policy
# Create the A2C model with an MLP policy
model = A2C(
    "MlpPolicy", 
    env, 
    verbose=1, 
    tensorboard_log=log_path,
    learning_rate=0.001,  # Learning rate for the optimizer
    n_steps=5,  # Number of steps to run for each environment per update
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Train the model for a specific number of timesteps
model.learn(total_timesteps=10000)

# Save the model
model.save(model_save_path)

# Evaluate the model
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
print(f"Mean reward: {mean_reward}, Std reward: {std_reward}")

# Optionally, you can load the model later for further training or evaluation
# loaded_model = DQN.load(model_save_path, env=env)
# Out:
# Logging to Training/Logs/A2C_1
# side1-counter 3 : S1 0  S4 6
# side2-counter 4 : S2 22  S7 6
# side3-counter 4 : S3 5  S6 23
# side4-counter 4 : S5 3  S8 24
# Cycle Finished at 16 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S4 19
# side2-counter 4 : S2 13  S7 5
# side3-counter 4 : S3 6  S6 10
# side4-counter 4 : S5 3  S8 19
# Cycle Finished at 32 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 13
# side2-counter 4 : S2 7  S7 8
# side3-counter 4 : S3 5  S6 8
# side4-counter 4 : S5 4  S8 10
# Cycle Finished at 48 in com4
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S5 2
# side2-counter 4 : S2 4  S7 6
# side3-counter 4 : S3 5  S6 11
# side4-counter 4 : S4 9  S8 13
# Cycle Finished at 64 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 4
# side2-counter 4 : S2 9  S6 14
# side3-counter 4 : S3 4  S4 15
# side4-counter 4 : S7 4  S8 12
# Cycle Finished at 80 in com5
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S4 19
# side2-counter 4 : S2 12  S6 14
# side3-counter 4 : S3 5  S7 8
# side4-counter 4 : S5 4  S8 9
# Cycle Finished at 96 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S5 3
# side2-counter 4 : S2 8  S6 11
# side3-counter 4 : S3 6  S7 6
# side4-counter 4 : S4 9  S8 14
# Cycle Finished at 112 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 9
# side2-counter 4 : S2 9  S6 10
# side3-counter 4 : S3 5  S4 9
# side4-counter 4 : S7 9  S8 14
# Cycle Finished at 128 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 13
# side2-counter 4 : S3 5  S4 9
# side3-counter 4 : S5 4  S6 9
# side4-counter 4 : S7 10  S8 8
# Cycle Finished at 144 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 3  S2 9
# side2-counter 4 : S3 5  S7 4
# side3-counter 4 : S4 11  S8 14
# side4-counter 4 : S5 2  S6 14
# Cycle Finished at 160 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 1
# side2-counter 4 : S2 20  S6 13
# side3-counter 4 : S3 5  S7 8
# side4-counter 4 : S5 3  S8 14
# Cycle Finished at 176 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 7
# side2-counter 4 : S3 4  S4 11
# side3-counter 4 : S5 4  S6 11
# side4-counter 4 : S7 5  S8 12
# Cycle Finished at 192 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 3  S4 11
# side2-counter 4 : S2 16  S7 5
# side3-counter 4 : S3 6  S6 12
# side4-counter 4 : S5 4  S8 6
# Cycle Finished at 208 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 9
# side2-counter 4 : S2 10  S6 14
# side3-counter 4 : S3 6  S7 10
# side4-counter 4 : S5 2  S8 8
# Cycle Finished at 224 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 4
# side2-counter 4 : S2 9  S7 5
# side3-counter 4 : S3 6  S6 14
# side4-counter 4 : S4 11  S8 17
# Cycle Finished at 240 in com7
# Setting min-density to 0.8
# side1-counter 3 : S1 1  S5 4
# side2-counter 4 : S2 25  S6 24
# side3-counter 4 : S3 5  S7 7
# side4-counter 4 : S4 26  S8 30
# Cycle Finished at 16 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S4 23
# side2-counter 4 : S2 11  S6 12
# side3-counter 4 : S3 5  S7 8
# side4-counter 4 : S5 3  S8 20
# Cycle Finished at 32 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 0
# side2-counter 4 : S2 6  S6 11
# side3-counter 4 : S3 6  S4 12
# side4-counter 4 : S7 0  S8 12
# Cycle Finished at 48 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S4 12
# side2-counter 4 : S2 12  S6 14
# side3-counter 4 : S3 5  S7 8
# side4-counter 4 : S5 3  S8 10
# Cycle Finished at 64 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 4
# side2-counter 4 : S2 8  S6 10
# side3-counter 4 : S3 6  S7 6
# side4-counter 4 : S4 10  S8 8
# Cycle Finished at 80 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 3
# side2-counter 4 : S2 12  S6 16
# side3-counter 4 : S3 6  S7 7
# side4-counter 4 : S4 12  S8 9
# Cycle Finished at 96 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 6
# side2-counter 4 : S3 5  S7 6
# side3-counter 4 : S4 7  S8 12
# side4-counter 4 : S5 2  S6 12
# Cycle Finished at 112 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 1
# side2-counter 4 : S2 14  S6 10
# side3-counter 4 : S3 5  S4 9
# side4-counter 4 : S7 1  S8 8
# Cycle Finished at 128 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 11
# side2-counter 4 : S3 7  S4 12
# side3-counter 4 : S5 4  S6 8
# side4-counter 4 : S7 9  S8 8
# Cycle Finished at 144 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 12
# side2-counter 4 : S3 5  S7 4
# side3-counter 4 : S4 10  S8 15
# side4-counter 4 : S5 4  S6 11
# Cycle Finished at 160 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 1
# side2-counter 4 : S2 13  S7 7
# side3-counter 4 : S3 5  S6 9
# side4-counter 4 : S4 15  S8 9
# Cycle Finished at 176 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 4
# side2-counter 4 : S2 10  S6 14
# side3-counter 4 : S3 6  S4 12
# side4-counter 4 : S7 4  S8 10
# Cycle Finished at 192 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 4
# side2-counter 4 : S2 13  S6 12
# side3-counter 4 : S3 6  S7 8
# side4-counter 4 : S4 12  S8 14
# Cycle Finished at 208 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 2
# side2-counter 4 : S2 12  S6 15
# side3-counter 4 : S3 6  S7 10
# side4-counter 4 : S4 10  S8 12
# Cycle Finished at 224 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 4
# side2-counter 4 : S2 10  S6 10
# side3-counter 4 : S3 7  S4 14
# side4-counter 4 : S7 4  S8 13
# Cycle Finished at 240 in com5
# Setting min-density to 0.8
# side1-counter 3 : S1 6  S4 11
# side2-counter 4 : S2 20  S6 28
# side3-counter 4 : S3 6  S7 6
# side4-counter 4 : S5 5  S8 21
# Cycle Finished at 16 in com3
# Setting min-density to 1.25
# side1-counter 4 : S1 4  S2 10
# side2-counter 4 : S3 7  S4 21
# side3-counter 4 : S5 6  S6 16
# side4-counter 4 : S7 11  S8 15
# Cycle Finished at 32 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 6  S4 12
# side2-counter 4 : S2 9  S7 3
# side3-counter 4 : S3 8  S6 17
# side4-counter 4 : S5 4  S8 9
# Cycle Finished at 48 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 3
# side2-counter 4 : S2 11  S6 10
# side3-counter 4 : S3 7  S7 5
# side4-counter 4 : S4 10  S8 12
# Cycle Finished at 64 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S4 12
# side2-counter 4 : S2 14  S6 15
# side3-counter 4 : S3 4  S7 6
# side4-counter 4 : S5 6  S8 13
# Cycle Finished at 80 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 6  S2 11
# side2-counter 4 : S3 9  S4 13
# side3-counter 4 : S5 6  S6 14
# side4-counter 4 : S7 12  S8 10
# Cycle Finished at 96 in com1
# Setting min-density to 1.5
# side1-counter 4 : S1 5  S2 10
# side2-counter 4 : S3 7  S4 16
# side3-counter 4 : S5 8  S6 15
# side4-counter 4 : S7 5  S8 14
# Cycle Finished at 112 in com1
# Setting min-density to 1.25
# side1-counter 4 : S1 6  S5 4
# side2-counter 4 : S2 9  S6 13
# side3-counter 4 : S3 6  S4 10
# side4-counter 4 : S7 4  S8 12
# Cycle Finished at 128 in com5
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S4 13
# side2-counter 4 : S2 11  S7 5
# side3-counter 4 : S3 6  S6 11
# side4-counter 4 : S5 5  S8 11
# Cycle Finished at 144 in com4
# Setting min-density to 1.25
# side1-counter 4 : S1 6  S4 8
# side2-counter 4 : S2 9  S7 6
# side3-counter 4 : S3 10  S6 12
# side4-counter 4 : S5 5  S8 12
# Cycle Finished at 160 in com4
# Setting min-density to 1.25
# side1-counter 4 : S1 6  S5 5
# side2-counter 4 : S2 9  S6 11
# side3-counter 4 : S3 6  S7 4
# side4-counter 4 : S4 11  S8 8
# Cycle Finished at 176 in com6
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S5 6
# side2-counter 4 : S2 9  S6 9
# side3-counter 4 : S3 7  S7 7
# side4-counter 4 : S4 10  S8 9
# Cycle Finished at 192 in com6
# Setting min-density to 1.0
# side1-counter 4 : S1 8  S5 5
# side2-counter 4 : S2 16  S6 13
# side3-counter 4 : S3 9  S4 9
# side4-counter 4 : S7 5  S8 8
# Cycle Finished at 208 in com5
# Setting min-density to 1.0
# side1-counter 4 : S1 6  S4 11
# side2-counter 4 : S2 12  S6 13
# side3-counter 4 : S3 6  S7 6
# side4-counter 4 : S5 4  S8 16
# Cycle Finished at 224 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 8  S4 13
# side2-counter 4 : S2 11  S7 6
# side3-counter 4 : S3 8  S6 12
# side4-counter 4 : S5 6  S8 10
# Cycle Finished at 240 in com4
# Setting min-density to 1.5
# side1-counter 3 : S1 3  S2 12
# side2-counter 4 : S3 7  S7 1
# side3-counter 4 : S4 22  S8 26
# side4-counter 4 : S5 6  S6 26
# Cycle Finished at 16 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 15
# side2-counter 4 : S3 12  S4 19
# side3-counter 4 : S5 2  S6 13
# side4-counter 4 : S7 4  S8 25
# Cycle Finished at 32 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 9
# side2-counter 4 : S2 12  S6 9
# side3-counter 4 : S3 10  S7 4
# side4-counter 4 : S5 3  S8 14
# Cycle Finished at 48 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 11
# side2-counter 4 : S2 9  S6 18
# side3-counter 4 : S3 12  S7 2
# side4-counter 4 : S5 2  S8 11
# Cycle Finished at 64 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S4 8
# side2-counter 4 : S2 9  S6 13
# side3-counter 4 : S3 12  S7 4
# side4-counter 4 : S5 4  S8 16
# Cycle Finished at 80 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S4 9
# side2-counter 4 : S2 9  S6 13
# side3-counter 4 : S3 9  S7 4
# side4-counter 4 : S5 4  S8 10
# Cycle Finished at 96 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S5 2
# side2-counter 4 : S2 5  S6 14
# side3-counter 4 : S3 9  S4 10
# side4-counter 4 : S7 2  S8 12
# Cycle Finished at 112 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 4
# side2-counter 4 : S2 9  S6 11
# side3-counter 4 : S3 11  S4 7
# side4-counter 4 : S7 4  S8 10
# Cycle Finished at 128 in com5
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S4 14
# side2-counter 4 : S2 10  S6 12
# side3-counter 4 : S3 11  S7 4
# side4-counter 4 : S5 4  S8 10
# Cycle Finished at 144 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 3  S2 21
# side2-counter 4 : S3 8  S4 16
# side3-counter 4 : S5 2  S6 13
# side4-counter 4 : S7 2  S8 12
# Cycle Finished at 160 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S2 12
# side2-counter 4 : S3 10  S4 14
# side3-counter 4 : S5 8  S6 12
# side4-counter 4 : S7 4  S8 11
# Cycle Finished at 176 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S4 5
# side2-counter 4 : S2 10  S6 11
# side3-counter 4 : S3 10  S7 5
# side4-counter 4 : S5 4  S8 15
# Cycle Finished at 192 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S5 2
# side2-counter 4 : S2 14  S7 2
# side3-counter 4 : S3 10  S6 10
# side4-counter 4 : S4 11  S8 8
# Cycle Finished at 208 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 5
# side2-counter 4 : S2 14  S6 14
# side3-counter 4 : S3 13  S7 4
# side4-counter 4 : S4 8  S8 12
# Cycle Finished at 224 in com6
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S2 4
# side2-counter 4 : S3 10  S4 11
# side3-counter 4 : S5 4  S6 9
# side4-counter 4 : S7 9  S8 11
# Cycle Finished at 240 in com1
# Setting min-density to 1.0
# side1-counter 3 : S1 5  S4 9
# side2-counter 4 : S2 28  S7 4
# side3-counter 4 : S3 3  S6 25
# side4-counter 4 : S5 3  S8 31
# Cycle Finished at 16 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S2 5
# side2-counter 4 : S3 5  S7 2
# side3-counter 4 : S4 25  S8 19
# side4-counter 4 : S5 4  S6 12
# Cycle Finished at 32 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 8
# side2-counter 4 : S2 9  S6 12
# side3-counter 4 : S3 6  S7 4
# side4-counter 4 : S5 4  S8 9
# Cycle Finished at 48 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S4 13
# side2-counter 4 : S2 11  S7 4
# side3-counter 4 : S3 4  S6 11
# side4-counter 4 : S5 4  S8 13
# Cycle Finished at 64 in com4
# Setting min-density to 1.0
# side1-counter 4 : S1 6  S2 12
# side2-counter 4 : S3 3  S4 13
# side3-counter 4 : S5 4  S6 8
# side4-counter 4 : S7 4  S8 12
# Cycle Finished at 80 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S4 13
# side2-counter 4 : S2 10  S6 11
# side3-counter 4 : S3 11  S7 4
# side4-counter 4 : S5 3  S8 9
# Cycle Finished at 96 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S4 8
# side2-counter 4 : S2 12  S7 2
# side3-counter 4 : S3 8  S6 11
# side4-counter 4 : S5 4  S8 11
# Cycle Finished at 112 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 4
# side2-counter 4 : S2 15  S6 9
# side3-counter 4 : S3 6  S4 8
# side4-counter 4 : S7 4  S8 12
# Cycle Finished at 128 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 9
# side2-counter 4 : S3 6  S4 14
# side3-counter 4 : S5 2  S6 11
# side4-counter 4 : S7 4  S8 13
# Cycle Finished at 144 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S4 9
# side2-counter 4 : S2 10  S7 3
# side3-counter 4 : S3 5  S6 12
# side4-counter 4 : S5 4  S8 11
# Cycle Finished at 160 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 12
# side2-counter 4 : S2 9  S7 4
# side3-counter 4 : S3 7  S6 9
# side4-counter 4 : S5 2  S8 10
# Cycle Finished at 176 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 10  S5 4
# side2-counter 4 : S2 12  S7 3
# side3-counter 4 : S3 6  S6 13
# side4-counter 4 : S4 17  S8 10
# Cycle Finished at 192 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S4 15
# side2-counter 4 : S2 10  S6 7
# side3-counter 4 : S3 4  S7 4
# side4-counter 4 : S5 3  S8 13
# Cycle Finished at 208 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S4 10
# side2-counter 4 : S2 11  S7 3
# side3-counter 4 : S3 6  S6 13
# side4-counter 4 : S5 3  S8 12
# Cycle Finished at 224 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S2 9
# side2-counter 4 : S3 5  S4 8
# side3-counter 4 : S5 4  S6 10
# side4-counter 4 : S7 4  S8 14
# Cycle Finished at 240 in com1
# Setting min-density to 1.0
# side1-counter 3 : S1 3  S5 5
# side2-counter 4 : S2 22  S6 29
# side3-counter 4 : S3 6  S7 6
# side4-counter 4 : S4 24  S8 24
# Cycle Finished at 16 in com6
# Setting min-density to 1.0
# side1-counter 4 : S1 3  S4 26
# side2-counter 4 : S2 12  S7 4
# side3-counter 4 : S3 10  S6 12
# side4-counter 4 : S5 5  S8 22
# Cycle Finished at 32 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S2 8
# side2-counter 4 : S3 5  S7 5
# side3-counter 4 : S4 12  S8 10
# side4-counter 4 : S5 4  S6 10
# Cycle Finished at 48 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 0
# side2-counter 4 : S2 9  S6 11
# side3-counter 4 : S3 9  S7 7
# side4-counter 4 : S5 4  S8 11
# Cycle Finished at 64 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 4
# side2-counter 4 : S2 0  S7 4
# side3-counter 4 : S3 7  S6 11
# side4-counter 4 : S4 12  S8 9
# Cycle Finished at 80 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 11
# side2-counter 4 : S2 13  S7 4
# side3-counter 4 : S3 6  S6 13
# side4-counter 4 : S5 5  S8 18
# Cycle Finished at 96 in com4
# Setting min-density to 1.0
# side1-counter 4 : S1 3  S2 9
# side2-counter 4 : S3 7  S4 14
# side3-counter 4 : S5 5  S6 12
# side4-counter 4 : S7 6  S8 10
# Cycle Finished at 112 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 5
# side2-counter 4 : S2 15  S6 11
# side3-counter 4 : S3 8  S7 6
# side4-counter 4 : S4 10  S8 10
# Cycle Finished at 128 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S4 11
# side2-counter 4 : S2 13  S7 5
# side3-counter 4 : S3 6  S6 12
# side4-counter 4 : S5 5  S8 11
# Cycle Finished at 144 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 10
# side2-counter 4 : S3 6  S4 10
# side3-counter 4 : S5 6  S6 9
# side4-counter 4 : S7 6  S8 8
# Cycle Finished at 160 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 3  S4 11
# side2-counter 4 : S2 13  S6 9
# side3-counter 4 : S3 10  S7 5
# side4-counter 4 : S5 5  S8 12
# Cycle Finished at 176 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 3
# side2-counter 4 : S2 9  S6 11
# side3-counter 4 : S3 9  S4 8
# side4-counter 4 : S7 3  S8 11
# Cycle Finished at 192 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 6
# side2-counter 4 : S2 12  S6 11
# side3-counter 4 : S3 7  S7 5
# side4-counter 4 : S4 10  S8 12
# Cycle Finished at 208 in com6
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S2 5
# side2-counter 4 : S3 8  S4 9
# side3-counter 4 : S5 7  S6 12
# side4-counter 4 : S7 7  S8 10
# Cycle Finished at 224 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S4 12
# side2-counter 4 : S2 11  S6 7
# side3-counter 4 : S3 14  S7 6
# side4-counter 4 : S5 4  S8 8
# Cycle Finished at 240 in com3
# Setting min-density to 1.0
# side1-counter 3 : S1 1  S4 4
# side2-counter 4 : S2 23  S6 27
# side3-counter 4 : S3 3  S7 12
# side4-counter 4 : S5 3  S8 23
# Cycle Finished at 16 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 9
# side2-counter 4 : S3 3  S7 12
# side3-counter 4 : S4 17  S8 18
# side4-counter 4 : S5 3  S6 16
# Cycle Finished at 32 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 11
# side2-counter 4 : S3 3  S7 9
# side3-counter 4 : S4 15  S8 8
# side4-counter 4 : S5 5  S6 18
# Cycle Finished at 48 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 2
# side2-counter 4 : S2 11  S7 11
# side3-counter 4 : S3 3  S6 17
# side4-counter 4 : S4 10  S8 11
# Cycle Finished at 64 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 7
# side2-counter 4 : S2 11  S6 16
# side3-counter 4 : S3 4  S7 10
# side4-counter 4 : S4 12  S8 12
# Cycle Finished at 80 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 4
# side2-counter 4 : S3 5  S4 14
# side3-counter 4 : S5 3  S6 10
# side4-counter 4 : S7 15  S8 11
# Cycle Finished at 96 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 6
# side2-counter 4 : S2 9  S6 13
# side3-counter 4 : S3 3  S7 9
# side4-counter 4 : S4 9  S8 8
# Cycle Finished at 112 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 6
# side2-counter 4 : S3 4  S7 10
# side3-counter 4 : S4 10  S8 11
# side4-counter 4 : S5 4  S6 13
# Cycle Finished at 128 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 3
# side2-counter 4 : S2 10  S6 8
# side3-counter 4 : S3 4  S7 13
# side4-counter 4 : S4 9  S8 9
# Cycle Finished at 144 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 4
# side2-counter 4 : S2 11  S7 12
# side3-counter 4 : S3 4  S6 14
# side4-counter 4 : S4 11  S8 14
# Cycle Finished at 160 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 18
# side2-counter 4 : S2 11  S7 26
# side3-counter 4 : S3 7  S6 8
# side4-counter 4 : S5 3  S8 18
# Cycle Finished at 176 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 11
# side2-counter 4 : S2 11  S7 9
# side3-counter 4 : S3 4  S6 11
# side4-counter 4 : S5 4  S8 15
# Cycle Finished at 192 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 3
# side2-counter 4 : S2 8  S7 2
# side3-counter 4 : S3 4  S6 14
# side4-counter 4 : S5 3  S8 12
# Cycle Finished at 208 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 3
# side2-counter 4 : S2 9  S7 11
# side3-counter 4 : S3 2  S6 11
# side4-counter 4 : S4 12  S8 15
# Cycle Finished at 224 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 5
# side2-counter 4 : S2 16  S6 10
# side3-counter 4 : S3 4  S7 11
# side4-counter 4 : S4 15  S8 16
# Cycle Finished at 240 in com6
# Setting min-density to 0.8
# side1-counter 3 : S1 6  S4 8
# side2-counter 4 : S2 25  S7 8
# side3-counter 4 : S3 3  S6 27
# side4-counter 4 : S5 4  S8 26
# Cycle Finished at 16 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 9
# side2-counter 4 : S3 4  S4 21
# side3-counter 4 : S5 8  S6 13
# side4-counter 4 : S7 11  S8 13
# Cycle Finished at 32 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S5 6
# side2-counter 4 : S2 7  S6 16
# side3-counter 4 : S3 3  S7 11
# side4-counter 4 : S4 14  S8 10
# Cycle Finished at 48 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 6
# side2-counter 4 : S3 4  S4 13
# side3-counter 4 : S5 6  S6 13
# side4-counter 4 : S7 11  S8 14
# Cycle Finished at 64 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 3  S5 5
# side2-counter 4 : S2 14  S7 5
# side3-counter 4 : S3 5  S6 10
# side4-counter 4 : S4 11  S8 9
# Cycle Finished at 80 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 5
# side2-counter 4 : S2 15  S6 7
# side3-counter 4 : S3 3  S4 7
# side4-counter 4 : S7 5  S8 8
# Cycle Finished at 96 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 5
# side2-counter 4 : S2 9  S7 8
# side3-counter 4 : S3 3  S6 11
# side4-counter 4 : S4 8  S8 13
# Cycle Finished at 112 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 12
# side2-counter 4 : S2 10  S7 4
# side3-counter 4 : S3 3  S6 9
# side4-counter 4 : S5 5  S8 11
# Cycle Finished at 128 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 10
# side2-counter 4 : S3 3  S4 20
# side3-counter 4 : S5 6  S6 11
# side4-counter 4 : S7 10  S8 12
# Cycle Finished at 144 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 10
# side2-counter 4 : S3 4  S7 3
# side3-counter 4 : S4 12  S8 12
# side4-counter 4 : S5 5  S6 11
# Cycle Finished at 160 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S4 3
# side2-counter 4 : S2 10  S7 9
# side3-counter 4 : S3 2  S6 12
# side4-counter 4 : S5 5  S8 17
# Cycle Finished at 176 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 5
# side2-counter 4 : S2 6  S7 11
# side3-counter 4 : S3 3  S6 11
# side4-counter 4 : S4 16  S8 12
# Cycle Finished at 192 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 7
# side2-counter 4 : S2 12  S6 10
# side3-counter 4 : S3 3  S7 11
# side4-counter 4 : S4 9  S8 6
# Cycle Finished at 208 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 7
# side2-counter 4 : S2 12  S6 12
# side3-counter 4 : S3 8  S4 13
# side4-counter 4 : S7 7  S8 9
# Cycle Finished at 224 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 12
# side2-counter 4 : S2 10  S6 8
# side3-counter 4 : S3 4  S7 9
# side4-counter 4 : S5 4  S8 9
# Cycle Finished at 240 in com3
# Setting min-density to 0.8
# side1-counter 3 : S1 1  S5 5
# side2-counter 4 : S2 31  S6 21
# side3-counter 4 : S3 7  S4 24
# side4-counter 4 : S7 5  S8 24
# Cycle Finished at 16 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 6
# side2-counter 4 : S2 11  S7 2
# side3-counter 4 : S3 8  S6 13
# side4-counter 4 : S4 16  S8 22
# Cycle Finished at 32 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 6
# side2-counter 4 : S3 6  S7 4
# side3-counter 4 : S4 13  S8 8
# side4-counter 4 : S5 10  S6 13
# Cycle Finished at 48 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 12
# side2-counter 4 : S3 6  S4 6
# side3-counter 4 : S5 8  S6 11
# side4-counter 4 : S7 9  S8 12
# Cycle Finished at 64 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 15
# side2-counter 4 : S3 9  S4 12
# side3-counter 4 : S5 6  S6 8
# side4-counter 4 : S7 8  S8 14
# Cycle Finished at 80 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 16
# side2-counter 4 : S3 7  S7 6
# side3-counter 4 : S4 15  S8 13
# side4-counter 4 : S5 7  S6 9
# Cycle Finished at 96 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 4
# side2-counter 4 : S2 10  S7 9
# side3-counter 4 : S3 8  S6 9
# side4-counter 4 : S4 13  S8 8
# Cycle Finished at 112 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 7
# side2-counter 4 : S2 11  S7 8
# side3-counter 4 : S3 4  S6 10
# side4-counter 4 : S4 12  S8 15
# Cycle Finished at 128 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 6
# side2-counter 4 : S3 8  S7 9
# side3-counter 4 : S4 9  S8 11
# side4-counter 4 : S5 7  S6 14
# Cycle Finished at 144 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 14
# side2-counter 4 : S3 9  S7 8
# side3-counter 4 : S4 11  S8 10
# side4-counter 4 : S5 9  S6 19
# Cycle Finished at 160 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 5
# side2-counter 4 : S2 15  S7 8
# side3-counter 4 : S3 8  S6 10
# side4-counter 4 : S4 11  S8 14
# Cycle Finished at 176 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S4 16
# side2-counter 4 : S2 16  S7 29
# side3-counter 4 : S3 6  S6 13
# side4-counter 4 : S5 6  S8 10
# Cycle Finished at 192 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 10
# side2-counter 4 : S3 10  S4 9
# side3-counter 4 : S5 7  S6 12
# side4-counter 4 : S7 11  S8 12
# Cycle Finished at 208 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 5
# side2-counter 4 : S2 18  S7 6
# side3-counter 4 : S3 9  S6 15
# side4-counter 4 : S5 7  S8 9
# Cycle Finished at 224 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 12
# side2-counter 4 : S3 8  S4 10
# side3-counter 4 : S5 11  S6 7
# side4-counter 4 : S7 12  S8 12
# Cycle Finished at 240 in com1
# Setting min-density to 0.8
# side1-counter 3 : S1 2  S5 5
# side2-counter 4 : S2 23  S6 21
# side3-counter 4 : S3 4  S4 22
# side4-counter 4 : S7 5  S8 22
# Cycle Finished at 16 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 16
# side2-counter 4 : S3 5  S4 18
# side3-counter 4 : S5 6  S6 13
# side4-counter 4 : S7 2  S8 17
# Cycle Finished at 32 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 6
# side2-counter 4 : S2 14  S6 9
# side3-counter 4 : S3 5  S7 2
# side4-counter 4 : S4 11  S8 10
# Cycle Finished at 48 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 3
# side2-counter 4 : S2 10  S7 2
# side3-counter 4 : S3 8  S6 14
# side4-counter 4 : S4 14  S8 14
# Cycle Finished at 64 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S2 9
# side2-counter 4 : S3 5  S4 12
# side3-counter 4 : S5 6  S6 10
# side4-counter 4 : S7 2  S8 10
# Cycle Finished at 80 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S5 6
# side2-counter 4 : S2 14  S6 10
# side3-counter 4 : S3 6  S4 17
# side4-counter 4 : S7 6  S8 12
# Cycle Finished at 96 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 11
# side2-counter 4 : S3 7  S7 2
# side3-counter 4 : S4 10  S8 10
# side4-counter 4 : S5 6  S6 13
# Cycle Finished at 112 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 16
# side2-counter 4 : S3 6  S7 1
# side3-counter 4 : S4 11  S8 17
# side4-counter 4 : S5 4  S6 11
# Cycle Finished at 128 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S4 1
# side2-counter 4 : S2 11  S6 13
# side3-counter 4 : S3 5  S7 2
# side4-counter 4 : S5 6  S8 12
# Cycle Finished at 144 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 5
# side2-counter 4 : S2 4  S6 11
# side3-counter 4 : S3 5  S7 1
# side4-counter 4 : S4 11  S8 9
# Cycle Finished at 160 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S2 4
# side2-counter 4 : S3 5  S7 2
# side3-counter 4 : S4 11  S8 5
# side4-counter 4 : S5 4  S6 12
# Cycle Finished at 176 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S4 5
# side2-counter 4 : S2 11  S7 2
# side3-counter 4 : S3 4  S6 11
# side4-counter 4 : S5 6  S8 5
# Cycle Finished at 192 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 5
# side2-counter 4 : S2 9  S7 1
# side3-counter 4 : S3 6  S6 14
# side4-counter 4 : S4 11  S8 11
# Cycle Finished at 208 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S5 5
# side2-counter 4 : S2 13  S7 2
# side3-counter 4 : S3 5  S6 9
# side4-counter 4 : S4 9  S8 9
# Cycle Finished at 224 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 5
# side2-counter 4 : S2 15  S6 20
# side3-counter 4 : S3 4  S4 13
# side4-counter 4 : S7 5  S8 12
# Cycle Finished at 240 in com5
# Setting min-density to 0.8
# side1-counter 3 : S1 4  S2 16
# side2-counter 4 : S3 7  S7 8
# side3-counter 4 : S4 22  S8 24
# side4-counter 4 : S5 2  S6 26
# Cycle Finished at 16 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 3
# side2-counter 4 : S2 19  S6 17
# side3-counter 4 : S3 8  S7 8
# side4-counter 4 : S4 20  S8 24
# Cycle Finished at 32 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 4
# side2-counter 4 : S2 11  S6 18
# side3-counter 4 : S3 11  S7 9
# side4-counter 4 : S4 9  S8 13
# Cycle Finished at 48 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 18
# side2-counter 4 : S2 8  S7 24
# side3-counter 4 : S3 5  S6 12
# side4-counter 4 : S5 3  S8 10
# Cycle Finished at 64 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 9
# side2-counter 4 : S2 9  S6 16
# side3-counter 4 : S3 11  S7 6
# side4-counter 4 : S5 3  S8 12
# Cycle Finished at 80 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S2 10
# side2-counter 4 : S3 7  S7 7
# side3-counter 4 : S4 9  S8 13
# side4-counter 4 : S5 4  S6 21
# Cycle Finished at 96 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 4
# side2-counter 4 : S2 10  S7 7
# side3-counter 4 : S3 4  S6 14
# side4-counter 4 : S4 10  S8 11
# Cycle Finished at 112 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 5
# side2-counter 4 : S3 7  S4 12
# side3-counter 4 : S5 4  S6 11
# side4-counter 4 : S7 10  S8 7
# Cycle Finished at 128 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S2 12
# side2-counter 4 : S3 7  S7 3
# side3-counter 4 : S4 17  S8 14
# side4-counter 4 : S5 4  S6 9
# Cycle Finished at 144 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 3  S4 1
# side2-counter 4 : S2 12  S7 8
# side3-counter 4 : S3 10  S6 11
# side4-counter 4 : S5 3  S8 13
# Cycle Finished at 160 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 8
# side2-counter 4 : S3 8  S4 9
# side3-counter 4 : S5 3  S6 8
# side4-counter 4 : S7 7  S8 12
# Cycle Finished at 176 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 9  S2 11
# side2-counter 4 : S3 8  S4 8
# side3-counter 4 : S5 4  S6 9
# side4-counter 4 : S7 7  S8 11
# Cycle Finished at 192 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 3  S2 14
# side2-counter 4 : S3 8  S7 4
# side3-counter 4 : S4 15  S8 8
# side4-counter 4 : S5 7  S6 13
# Cycle Finished at 208 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 4
# side2-counter 4 : S2 11  S6 12
# side3-counter 4 : S3 6  S7 12
# side4-counter 4 : S4 9  S8 8
# Cycle Finished at 224 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 17
# side2-counter 4 : S2 9  S7 5
# side3-counter 4 : S3 6  S6 13
# side4-counter 4 : S5 3  S8 12
# Cycle Finished at 240 in com4
# Setting min-density to 0.8
# side1-counter 3 : S1 1  S5 0
# side2-counter 4 : S2 23  S6 22
# side3-counter 4 : S3 11  S4 25
# side4-counter 4 : S7 1  S8 22
# Cycle Finished at 16 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S2 9
# side2-counter 4 : S3 9  S4 19
# side3-counter 4 : S5 5  S6 12
# side4-counter 4 : S7 4  S8 24
# Cycle Finished at 32 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 6
# side2-counter 4 : S2 15  S7 3
# side3-counter 4 : S3 10  S6 10
# side4-counter 4 : S4 11  S8 11
# Cycle Finished at 48 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S4 7
# side2-counter 4 : S2 11  S7 4
# side3-counter 4 : S3 7  S6 9
# side4-counter 4 : S5 8  S8 10
# Cycle Finished at 64 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S2 8
# side2-counter 4 : S3 8  S7 3
# side3-counter 4 : S4 10  S8 9
# side4-counter 4 : S5 9  S6 8
# Cycle Finished at 80 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S4 0
# side2-counter 4 : S2 14  S6 11
# side3-counter 4 : S3 9  S7 4
# side4-counter 4 : S5 7  S8 15
# Cycle Finished at 96 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 2
# side2-counter 4 : S2 1  S7 4
# side3-counter 4 : S3 9  S6 14
# side4-counter 4 : S4 18  S8 11
# Cycle Finished at 112 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 8
# side2-counter 4 : S2 8  S6 14
# side3-counter 4 : S3 9  S4 13
# side4-counter 4 : S7 8  S8 13
# Cycle Finished at 128 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S2 12
# side2-counter 4 : S3 9  S7 3
# side3-counter 4 : S4 9  S8 12
# side4-counter 4 : S5 10  S6 12
# Cycle Finished at 144 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 4
# side2-counter 4 : S2 11  S6 13
# side3-counter 4 : S3 9  S7 4
# side4-counter 4 : S4 14  S8 7
# Cycle Finished at 160 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 8
# side2-counter 4 : S2 10  S7 4
# side3-counter 4 : S3 8  S6 8
# side4-counter 4 : S4 13  S8 9
# Cycle Finished at 176 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S2 7
# side2-counter 4 : S3 5  S7 2
# side3-counter 4 : S4 8  S8 11
# side4-counter 4 : S5 7  S6 10
# Cycle Finished at 192 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S4 6
# side2-counter 4 : S2 14  S6 26
# side3-counter 4 : S3 10  S7 4
# side4-counter 4 : S5 7  S8 13
# Cycle Finished at 208 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S4 13
# side2-counter 4 : S2 13  S7 4
# side3-counter 4 : S3 13  S6 13
# side4-counter 4 : S5 6  S8 14
# Cycle Finished at 224 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 2
# side2-counter 4 : S2 14  S7 2
# side3-counter 4 : S3 8  S6 11
# side4-counter 4 : S4 14  S8 12
# Cycle Finished at 240 in com7
# Setting min-density to 0.8
# side1-counter 3 : S1 0  S5 3
# side2-counter 4 : S2 28  S7 4
# side3-counter 4 : S3 7  S6 25
# side4-counter 4 : S4 24  S8 22
# Cycle Finished at 16 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 7
# side2-counter 4 : S2 13  S6 12
# side3-counter 4 : S3 7  S4 18
# side4-counter 4 : S7 7  S8 25
# Cycle Finished at 32 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S2 16
# side2-counter 4 : S3 5  S7 2
# side3-counter 4 : S4 18  S8 10
# side4-counter 4 : S5 6  S6 17
# Cycle Finished at 48 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 5
# side2-counter 4 : S2 11  S6 14
# side3-counter 4 : S3 8  S4 8
# side4-counter 4 : S7 5  S8 10
# Cycle Finished at 64 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 3
# side2-counter 4 : S2 10  S6 10
# side3-counter 4 : S3 9  S4 14
# side4-counter 4 : S7 3  S8 14
# Cycle Finished at 80 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 6
# side2-counter 4 : S2 11  S6 12
# side3-counter 4 : S3 8  S4 10
# side4-counter 4 : S7 6  S8 12
# Cycle Finished at 96 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S4 12
# side2-counter 4 : S2 13  S6 14
# side3-counter 4 : S3 7  S7 6
# side4-counter 4 : S5 6  S8 10
# Cycle Finished at 112 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S2 14
# side2-counter 4 : S3 5  S4 11
# side3-counter 4 : S5 4  S6 13
# side4-counter 4 : S7 5  S8 8
# Cycle Finished at 128 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S4 5
# side2-counter 4 : S2 15  S6 20
# side3-counter 4 : S3 8  S7 5
# side4-counter 4 : S5 6  S8 12
# Cycle Finished at 144 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 3
# side2-counter 4 : S2 8  S6 11
# side3-counter 4 : S3 8  S7 4
# side4-counter 4 : S4 13  S8 11
# Cycle Finished at 160 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S2 4
# side2-counter 4 : S3 7  S7 4
# side3-counter 4 : S4 13  S8 13
# side4-counter 4 : S5 8  S6 11
# Cycle Finished at 176 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 0
# side2-counter 4 : S2 12  S6 13
# side3-counter 4 : S3 9  S7 6
# side4-counter 4 : S4 10  S8 12
# Cycle Finished at 192 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S2 8
# side2-counter 4 : S3 10  S4 9
# side3-counter 4 : S5 5  S6 10
# side4-counter 4 : S7 11  S8 9
# Cycle Finished at 208 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 6
# side2-counter 4 : S2 8  S7 3
# side3-counter 4 : S3 6  S6 13
# side4-counter 4 : S4 11  S8 8
# Cycle Finished at 224 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 0  S5 4
# side2-counter 4 : S2 11  S7 5
# side3-counter 4 : S3 8  S6 13
# side4-counter 4 : S4 10  S8 13
# Cycle Finished at 240 in com7
# Setting min-density to 0.8
# side1-counter 3 : S1 3  S5 6
# side2-counter 4 : S2 25  S6 20
# side3-counter 4 : S3 6  S7 4
# side4-counter 4 : S4 24  S8 26
# Cycle Finished at 16 in com6
# Setting min-density to 1.0
# side1-counter 4 : S1 8  S5 6
# side2-counter 4 : S2 10  S7 2
# side3-counter 4 : S3 5  S6 15
# side4-counter 4 : S4 12  S8 22
# Cycle Finished at 32 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S4 4
# side2-counter 4 : S2 12  S6 15
# side3-counter 4 : S3 6  S7 5
# side4-counter 4 : S5 5  S8 13
# Cycle Finished at 48 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 6  S5 4
# side2-counter 4 : S2 3  S6 20
# side3-counter 4 : S3 5  S7 3
# side4-counter 4 : S4 16  S8 14
# Cycle Finished at 64 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S2 4
# side2-counter 4 : S3 5  S4 7
# side3-counter 4 : S5 4  S6 9
# side4-counter 4 : S7 10  S8 9
# Cycle Finished at 80 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 14  S5 6
# side2-counter 4 : S2 14  S6 10
# side3-counter 4 : S3 4  S7 3
# side4-counter 4 : S4 16  S8 14
# Cycle Finished at 96 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S2 8
# side2-counter 4 : S3 5  S7 3
# side3-counter 4 : S4 10  S8 11
# side4-counter 4 : S5 4  S6 9
# Cycle Finished at 112 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S2 10
# side2-counter 4 : S3 4  S7 4
# side3-counter 4 : S4 13  S8 10
# side4-counter 4 : S5 6  S6 13
# Cycle Finished at 128 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 7  S5 4
# side2-counter 4 : S2 9  S6 13
# side3-counter 4 : S3 6  S4 12
# side4-counter 4 : S7 4  S8 13
# Cycle Finished at 144 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 12  S2 10
# side2-counter 4 : S3 5  S4 9
# side3-counter 4 : S5 5  S6 11
# side4-counter 4 : S7 3  S8 9
# Cycle Finished at 160 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S5 4
# side2-counter 4 : S2 15  S6 13
# side3-counter 4 : S3 8  S4 8
# side4-counter 4 : S7 4  S8 12
# Cycle Finished at 176 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 9  S2 10
# side2-counter 4 : S3 9  S7 3
# side3-counter 4 : S4 10  S8 17
# side4-counter 4 : S5 6  S6 16
# Cycle Finished at 192 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 10  S2 10
# side2-counter 4 : S3 7  S4 11
# side3-counter 4 : S5 4  S6 12
# side4-counter 4 : S7 4  S8 11
# Cycle Finished at 208 in com1
# Setting min-density to 1.0
# side1-counter 4 : S1 7  S5 6
# side2-counter 4 : S2 12  S7 3
# side3-counter 4 : S3 6  S6 13
# side4-counter 4 : S4 13  S8 9
# Cycle Finished at 224 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S2 4
# side2-counter 4 : S3 6  S4 11
# side3-counter 4 : S5 5  S6 11
# side4-counter 4 : S7 4  S8 13
# Cycle Finished at 240 in com1
# Setting min-density to 1.0
# side1-counter 3 : S1 3  S2 11
# side2-counter 4 : S3 7  S7 4
# side3-counter 4 : S4 26  S8 23
# side4-counter 4 : S5 4  S6 27
# Cycle Finished at 16 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S2 14
# side2-counter 4 : S3 6  S7 6
# side3-counter 4 : S4 13  S8 17
# side4-counter 4 : S5 6  S6 14
# Cycle Finished at 32 in com2
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S5 6
# side2-counter 4 : S2 10  S6 11
# side3-counter 4 : S3 8  S4 13
# side4-counter 4 : S7 6  S8 14
# Cycle Finished at 48 in com5
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S2 9
# side2-counter 4 : S3 6  S7 4
# side3-counter 4 : S4 12  S8 12
# side4-counter 4 : S5 7  S6 8
# Cycle Finished at 64 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S2 14
# side2-counter 4 : S3 6  S4 6
# side3-counter 4 : S5 5  S6 7
# side4-counter 4 : S7 9  S8 11
# Cycle Finished at 80 in com1
# Setting min-density to 1.25
# side1-counter 4 : S1 7  S2 10
# side2-counter 4 : S3 7  S7 4
# side3-counter 4 : S4 12  S8 11
# side4-counter 4 : S5 7  S6 7
# Cycle Finished at 96 in com2
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S5 5
# side2-counter 4 : S2 10  S6 10
# side3-counter 4 : S3 7  S7 7
# side4-counter 4 : S4 9  S8 14
# Cycle Finished at 112 in com6
# Setting min-density to 1.25
# side1-counter 4 : S1 6  S5 7
# side2-counter 4 : S2 12  S6 14
# side3-counter 4 : S3 12  S4 13
# side4-counter 4 : S7 7  S8 14
# Cycle Finished at 128 in com5
# Setting min-density to 1.25
# side1-counter 4 : S1 7  S5 6
# side2-counter 4 : S2 12  S7 5
# side3-counter 4 : S3 7  S6 11
# side4-counter 4 : S4 11  S8 10
# Cycle Finished at 144 in com7
# Setting min-density to 1.5
# side1-counter 4 : S1 5  S5 6
# side2-counter 4 : S2 9  S6 7
# side3-counter 4 : S3 8  S7 8
# side4-counter 4 : S4 15  S8 12
# Cycle Finished at 160 in com6
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S5 7
# side2-counter 4 : S2 11  S6 8
# side3-counter 4 : S3 6  S4 15
# side4-counter 4 : S7 7  S8 10
# Cycle Finished at 176 in com5
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S5 6
# side2-counter 4 : S2 13  S6 9
# side3-counter 4 : S3 7  S7 10
# side4-counter 4 : S4 16  S8 14
# Cycle Finished at 192 in com6
# Setting min-density to 1.25
# side1-counter 4 : S1 6  S2 4
# side2-counter 4 : S3 8  S7 8
# side3-counter 4 : S4 10  S8 13
# side4-counter 4 : S5 6  S6 18
# Cycle Finished at 208 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 6  S2 9
# side2-counter 4 : S3 5  S7 8
# side3-counter 4 : S4 14  S8 11
# side4-counter 4 : S5 5  S6 13
# Cycle Finished at 224 in com2
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S4 1
# side2-counter 4 : S2 12  S7 5
# side3-counter 4 : S3 7  S6 11
# side4-counter 4 : S5 6  S8 13
# Cycle Finished at 240 in com4
# Setting min-density to 0.8
# side1-counter 3 : S1 0  S5 5
# side2-counter 4 : S2 23  S6 24
# side3-counter 4 : S3 8  S7 8
# side4-counter 4 : S4 23  S8 26
# Cycle Finished at 16 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S2 5
# side2-counter 4 : S3 7  S7 6
# side3-counter 4 : S4 19  S8 24
# side4-counter 4 : S5 11  S6 9
# Cycle Finished at 32 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S2 17
# side2-counter 4 : S3 10  S4 14
# side3-counter 4 : S5 10  S6 15
# side4-counter 4 : S7 7  S8 8
# Cycle Finished at 48 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 11
# side2-counter 4 : S2 13  S6 19
# side3-counter 4 : S3 10  S7 8
# side4-counter 4 : S5 10  S8 12
# Cycle Finished at 64 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 2  S5 2
# side2-counter 4 : S2 9  S7 8
# side3-counter 4 : S3 7  S6 13
# side4-counter 4 : S4 9  S8 14
# Cycle Finished at 80 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 8
# side2-counter 4 : S2 14  S6 17
# side3-counter 4 : S3 12  S7 8
# side4-counter 4 : S4 13  S8 9
# Cycle Finished at 96 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S2 6
# side2-counter 4 : S3 7  S7 7
# side3-counter 4 : S4 9  S8 15
# side4-counter 4 : S5 11  S6 16
# Cycle Finished at 112 in com2
# Setting min-density to 1.25
# side1-counter 4 : S1 4  S5 2
# side2-counter 4 : S2 12  S7 8
# side3-counter 4 : S3 9  S6 9
# side4-counter 4 : S4 10  S8 10
# Cycle Finished at 128 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 9
# side2-counter 4 : S2 13  S7 5
# side3-counter 4 : S3 10  S6 11
# side4-counter 4 : S4 8  S8 10
# Cycle Finished at 144 in com7
# Setting min-density to 1.25
# side1-counter 4 : S1 3  S4 13
# side2-counter 4 : S2 13  S6 3
# side3-counter 4 : S3 9  S7 7
# side4-counter 4 : S5 10  S8 11
# Cycle Finished at 160 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S4 7
# side2-counter 4 : S2 37  S7 8
# side3-counter 4 : S3 9  S6 15
# side4-counter 4 : S5 6  S8 12
# Cycle Finished at 176 in com4
# Setting min-density to 1.0
# side1-counter 4 : S1 3  S2 21
# side2-counter 4 : S3 7  S4 10
# side3-counter 4 : S5 11  S6 10
# side4-counter 4 : S7 8  S8 11
# Cycle Finished at 192 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S2 12
# side2-counter 4 : S3 11  S7 4
# side3-counter 4 : S4 10  S8 4
# side4-counter 4 : S5 9  S6 10
# Cycle Finished at 208 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 4  S2 16
# side2-counter 4 : S3 10  S7 7
# side3-counter 4 : S4 11  S8 9
# side4-counter 4 : S5 8  S6 10
# Cycle Finished at 224 in com2
# Setting min-density to 1.0
# side1-counter 4 : S1 3  S2 14
# side2-counter 4 : S3 10  S7 7
# side3-counter 4 : S4 9  S8 10
# side4-counter 4 : S5 8  S6 13
# Cycle Finished at 240 in com2
# Setting min-density to 0.8
# side1-counter 3 : S1 2  S4 5
# side2-counter 4 : S2 23  S6 22
# side3-counter 4 : S3 5  S7 5
# side4-counter 4 : S5 0  S8 26
# Cycle Finished at 16 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 4
# side2-counter 4 : S3 6  S7 5
# side3-counter 4 : S4 26  S8 23
# side4-counter 4 : S5 0  S6 10
# Cycle Finished at 32 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 9
# side2-counter 4 : S2 11  S6 8
# side3-counter 4 : S3 6  S7 5
# side4-counter 4 : S5 0  S8 9
# Cycle Finished at 48 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 0
# side2-counter 4 : S2 9  S6 11
# side3-counter 4 : S3 3  S7 5
# side4-counter 4 : S4 14  S8 9
# Cycle Finished at 64 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 4
# side2-counter 4 : S3 6  S7 6
# side3-counter 4 : S4 13  S8 10
# side4-counter 4 : S5 0  S6 10
# Cycle Finished at 80 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 0
# side2-counter 4 : S2 11  S7 6
# side3-counter 4 : S3 7  S6 13
# side4-counter 4 : S4 8  S8 8
# Cycle Finished at 96 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 0
# side2-counter 4 : S2 12  S6 13
# side3-counter 4 : S3 5  S7 4
# side4-counter 4 : S4 9  S8 12
# Cycle Finished at 112 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 0
# side2-counter 4 : S2 16  S7 6
# side3-counter 4 : S3 4  S6 12
# side4-counter 4 : S4 10  S8 7
# Cycle Finished at 128 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 0
# side2-counter 4 : S2 16  S7 6
# side3-counter 4 : S3 5  S6 11
# side4-counter 4 : S4 14  S8 9
# Cycle Finished at 144 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 10
# side2-counter 4 : S3 6  S7 3
# side3-counter 4 : S4 9  S8 12
# side4-counter 4 : S5 0  S6 10
# Cycle Finished at 160 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 4
# side2-counter 4 : S2 8  S6 13
# side3-counter 4 : S3 7  S7 7
# side4-counter 4 : S5 0  S8 10
# Cycle Finished at 176 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 10
# side2-counter 4 : S3 4  S7 5
# side3-counter 4 : S4 10  S8 9
# side4-counter 4 : S5 0  S6 12
# Cycle Finished at 192 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 13
# side2-counter 4 : S3 6  S4 11
# side3-counter 4 : S5 0  S6 9
# side4-counter 4 : S7 6  S8 18
# Cycle Finished at 208 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 15
# side2-counter 4 : S3 6  S7 4
# side3-counter 4 : S4 8  S8 10
# side4-counter 4 : S5 0  S6 12
# Cycle Finished at 224 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 12
# side2-counter 4 : S3 5  S7 6
# side3-counter 4 : S4 17  S8 10
# side4-counter 4 : S5 0  S6 12
# Cycle Finished at 240 in com2
# Setting min-density to 0.8
# side1-counter 3 : S1 3  S5 0
# side2-counter 4 : S2 22  S6 27
# side3-counter 4 : S3 5  S4 26
# side4-counter 4 : S7 1  S8 24
# Cycle Finished at 16 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 3
# side2-counter 4 : S2 14  S6 14
# side3-counter 4 : S3 7  S4 21
# side4-counter 4 : S7 3  S8 25
# Cycle Finished at 32 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 3  S5 4
# side2-counter 4 : S2 14  S7 4
# side3-counter 4 : S3 6  S6 10
# side4-counter 4 : S4 14  S8 19
# Cycle Finished at 48 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S4 10
# side2-counter 4 : S2 9  S6 9
# side3-counter 4 : S3 7  S7 6
# side4-counter 4 : S5 3  S8 9
# Cycle Finished at 64 in com3
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 2
# side2-counter 4 : S2 7  S6 12
# side3-counter 4 : S3 6  S4 14
# side4-counter 4 : S7 2  S8 12
# Cycle Finished at 80 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 4
# side2-counter 4 : S2 10  S6 15
# side3-counter 4 : S3 9  S4 14
# side4-counter 4 : S7 4  S8 11
# Cycle Finished at 96 in com5
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S5 4
# side2-counter 4 : S2 16  S7 5
# side3-counter 4 : S3 4  S6 12
# side4-counter 4 : S4 12  S8 13
# Cycle Finished at 112 in com7
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S5 3
# side2-counter 4 : S2 12  S7 8
# side3-counter 4 : S3 5  S6 12
# side4-counter 4 : S4 13  S8 9
# Cycle Finished at 128 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S5 3
# side2-counter 4 : S2 9  S7 5
# side3-counter 4 : S3 4  S6 11
# side4-counter 4 : S4 11  S8 10
# Cycle Finished at 144 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 3
# side2-counter 4 : S2 10  S6 14
# side3-counter 4 : S3 4  S4 11
# side4-counter 4 : S7 3  S8 14
# Cycle Finished at 160 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 3
# side2-counter 4 : S2 10  S7 6
# side3-counter 4 : S3 7  S6 13
# side4-counter 4 : S4 13  S8 11
# Cycle Finished at 176 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S4 13
# side2-counter 4 : S2 12  S7 13
# side3-counter 4 : S3 5  S6 15
# side4-counter 4 : S5 3  S8 13
# Cycle Finished at 192 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 3
# side2-counter 4 : S2 11  S7 6
# side3-counter 4 : S3 5  S6 11
# side4-counter 4 : S4 10  S8 9
# Cycle Finished at 208 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 4
# side2-counter 4 : S2 10  S7 8
# side3-counter 4 : S3 6  S6 17
# side4-counter 4 : S4 17  S8 13
# Cycle Finished at 224 in com7
# Setting min-density to 1.0
# side1-counter 4 : S1 4  S2 4
# side2-counter 4 : S3 8  S7 8
# side3-counter 4 : S4 13  S8 13
# side4-counter 4 : S5 4  S6 18
# Cycle Finished at 240 in com2
# Setting min-density to 1.0
# side1-counter 3 : S1 5  S4 6
# side2-counter 4 : S2 24  S7 1
# side3-counter 4 : S3 2  S6 22
# side4-counter 4 : S5 4  S8 31
# Cycle Finished at 16 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 2
# side2-counter 4 : S2 5  S7 4
# side3-counter 4 : S3 2  S6 11
# side4-counter 4 : S4 21  S8 22
# Cycle Finished at 32 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 2
# side2-counter 4 : S2 11  S6 12
# side3-counter 4 : S3 2  S7 3
# ...
# side1-counter 4 : S1 4  S4 18
# side2-counter 4 : S2 13  S7 8
# side3-counter 4 : S3 10  S6 11
# side4-counter 4 : S5 4  S8 12
# Cycle Finished at 240 in com4
# Setting min-density to 1.0
# side1-counter 3 : S1 9  S5 2
# side2-counter 4 : S2 20  S6 24
# side3-counter 4 : S3 8  S4 25
# side4-counter 4 : S7 2  S8 20
# Cycle Finished at 16 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 9  S5 3
# side2-counter 4 : S2 9  S6 9
# side3-counter 4 : S3 10  S4 13
# side4-counter 4 : S7 3  S8 20
# Cycle Finished at 32 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 9  S5 3
# side2-counter 4 : S2 11  S6 8
# side3-counter 4 : S3 10  S4 10
# side4-counter 4 : S7 3  S8 14
# Cycle Finished at 48 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 8  S5 4
# side2-counter 4 : S2 14  S7 0
# side3-counter 4 : S3 10  S6 10
# side4-counter 4 : S4 9  S8 14
# Cycle Finished at 64 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 10  S2 4
# side2-counter 4 : S3 7  S7 0
# side3-counter 4 : S4 13  S8 11
# side4-counter 4 : S5 3  S6 9
# Cycle Finished at 80 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S4 0
# side2-counter 4 : S2 12  S7 0
# side3-counter 4 : S3 13  S6 12
# side4-counter 4 : S5 3  S8 7
# Cycle Finished at 96 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 14  S2 2
# side2-counter 4 : S3 9  S7 0
# side3-counter 4 : S4 12  S8 8
# side4-counter 4 : S5 4  S6 12
# Cycle Finished at 112 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S4 13
# side2-counter 4 : S2 14  S7 0
# side3-counter 4 : S3 6  S6 14
# side4-counter 4 : S5 4  S8 11
# Cycle Finished at 128 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 10  S2 12
# side2-counter 4 : S3 8  S4 18
# side3-counter 4 : S5 3  S6 12
# side4-counter 4 : S7 0  S8 10
# Cycle Finished at 144 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 9  S5 3
# side2-counter 4 : S2 11  S6 13
# side3-counter 4 : S3 6  S4 14
# side4-counter 4 : S7 3  S8 18
# Cycle Finished at 160 in com5
# Setting min-density to 0.8
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 15       |
# |    ep_rew_mean        | 0.864    |
# | time/                 |          |
# |    fps                | 2        |
# |    iterations         | 200      |
# |    time_elapsed       | 356      |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -15.9    |
# |    explained_variance | 0.67     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 199      |
# |    policy_loss        | 35.9     |
# |    value_loss         | 5.17     |
# ------------------------------------
# side1-counter 4 : S1 9  S5 4
# side2-counter 4 : S2 17  S7 0
# side3-counter 4 : S3 10  S6 9
# side4-counter 4 : S4 10  S8 9
# Cycle Finished at 176 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 11  S2 5
# side2-counter 4 : S3 9  S7 0
# side3-counter 4 : S4 10  S8 15
# side4-counter 4 : S5 3  S6 11
# Cycle Finished at 192 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 10  S5 4
# side2-counter 4 : S2 9  S6 14
# side3-counter 4 : S3 10  S4 10
# side4-counter 4 : S7 4  S8 7
# Cycle Finished at 208 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 9  S5 4
# side2-counter 4 : S2 9  S7 0
# side3-counter 4 : S3 6  S6 13
# side4-counter 4 : S4 12  S8 16
# Cycle Finished at 224 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 11  S2 16
# side2-counter 4 : S3 25  S4 6
# side3-counter 4 : S5 2  S6 14
# side4-counter 4 : S7 0  S8 10
# Cycle Finished at 240 in com1
# Setting min-density to 0.8
# side1-counter 3 : S1 2  S2 9
# side2-counter 4 : S3 7  S4 24
# side3-counter 4 : S5 3  S6 24
# side4-counter 4 : S7 5  S8 23
# Cycle Finished at 16 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 4
# side2-counter 4 : S2 20  S7 2
# side3-counter 4 : S3 6  S6 13
# side4-counter 4 : S4 17  S8 24
# Cycle Finished at 32 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 3
# side2-counter 4 : S2 9  S6 10
# side3-counter 4 : S3 10  S7 7
# side4-counter 4 : S4 10  S8 13
# Cycle Finished at 48 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 3
# side2-counter 4 : S2 12  S6 9
# side3-counter 4 : S3 9  S7 8
# side4-counter 4 : S4 14  S8 13
# Cycle Finished at 64 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 8
# side2-counter 4 : S2 10  S7 5
# side3-counter 4 : S3 6  S6 11
# side4-counter 4 : S5 4  S8 13
# Cycle Finished at 80 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S4 4
# side2-counter 4 : S2 11  S7 7
# side3-counter 4 : S3 10  S6 8
# side4-counter 4 : S5 3  S8 13
# Cycle Finished at 96 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 8
# side2-counter 4 : S2 6  S7 8
# side3-counter 4 : S3 8  S6 10
# side4-counter 4 : S5 3  S8 10
# Cycle Finished at 112 in com4
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 3
# side2-counter 4 : S2 4  S6 10
# side3-counter 4 : S3 7  S7 10
# side4-counter 4 : S4 9  S8 16
# Cycle Finished at 128 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 4
# side2-counter 4 : S2 12  S7 7
# side3-counter 4 : S3 9  S6 16
# side4-counter 4 : S4 12  S8 9
# Cycle Finished at 144 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 4
# side2-counter 4 : S3 6  S7 8
# side3-counter 4 : S4 8  S8 10
# side4-counter 4 : S5 4  S6 14
# Cycle Finished at 160 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 2
# side2-counter 4 : S2 8  S7 5
# side3-counter 4 : S3 8  S6 8
# side4-counter 4 : S4 11  S8 12
# Cycle Finished at 176 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 4
# side2-counter 4 : S2 9  S6 17
# side3-counter 4 : S3 10  S4 11
# side4-counter 4 : S7 4  S8 10
# Cycle Finished at 192 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 2
# side2-counter 4 : S2 13  S7 6
# side3-counter 4 : S3 8  S6 13
# side4-counter 4 : S4 10  S8 15
# Cycle Finished at 208 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 3
# side2-counter 4 : S2 9  S7 2
# side3-counter 4 : S3 12  S6 9
# side4-counter 4 : S4 9  S8 13
# Cycle Finished at 224 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 3
# side2-counter 4 : S2 11  S7 7
# side3-counter 4 : S3 6  S6 10
# side4-counter 4 : S4 8  S8 12
# Cycle Finished at 240 in com7
# Setting min-density to 0.8
# side1-counter 3 : S1 0  S5 3
# side2-counter 4 : S2 26  S7 4
# side3-counter 4 : S3 5  S6 23
# side4-counter 4 : S4 24  S8 26
# Cycle Finished at 16 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 3
# side2-counter 4 : S2 12  S6 13
# side3-counter 4 : S3 7  S7 4
# side4-counter 4 : S4 11  S8 15
# Cycle Finished at 32 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 6
# side2-counter 4 : S3 8  S7 3
# side3-counter 4 : S4 14  S8 8
# side4-counter 4 : S5 4  S6 8
# Cycle Finished at 48 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 2
# side2-counter 4 : S2 15  S6 11
# side3-counter 4 : S3 5  S4 8
# side4-counter 4 : S7 2  S8 17
# Cycle Finished at 64 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S5 2
# side2-counter 4 : S2 15  S6 9
# side3-counter 4 : S3 6  S4 13
# side4-counter 4 : S7 2  S8 13
# Cycle Finished at 80 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 15
# side2-counter 4 : S3 6  S7 4
# side3-counter 4 : S4 9  S8 12
# side4-counter 4 : S5 4  S6 9
# Cycle Finished at 96 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 12
# side2-counter 4 : S3 5  S4 7
# side3-counter 4 : S5 3  S6 9
# side4-counter 4 : S7 4  S8 9
# Cycle Finished at 112 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 10
# side2-counter 4 : S3 5  S7 2
# side3-counter 4 : S4 8  S8 13
# side4-counter 4 : S5 2  S6 16
# Cycle Finished at 128 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 11
# side2-counter 4 : S3 6  S7 4
# side3-counter 4 : S4 11  S8 16
# side4-counter 4 : S5 5  S6 8
# Cycle Finished at 144 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 13
# side2-counter 4 : S3 6  S4 9
# side3-counter 4 : S5 3  S6 12
# side4-counter 4 : S7 4  S8 13
# Cycle Finished at 160 in com1
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S5 3
# side2-counter 4 : S2 11  S7 4
# side3-counter 4 : S3 6  S6 13
# side4-counter 4 : S4 10  S8 13
# Cycle Finished at 176 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 4
# side2-counter 4 : S3 4  S7 3
# side3-counter 4 : S4 9  S8 11
# side4-counter 4 : S5 4  S6 12
# Cycle Finished at 192 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 8
# side2-counter 4 : S3 6  S7 3
# side3-counter 4 : S4 15  S8 8
# side4-counter 4 : S5 3  S6 11
# Cycle Finished at 208 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S2 14
# side2-counter 4 : S3 6  S7 4
# side3-counter 4 : S4 13  S8 17
# side4-counter 4 : S5 4  S6 11
# Cycle Finished at 224 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 1  S2 10
# side2-counter 4 : S3 6  S7 3
# side3-counter 4 : S4 10  S8 10
# side4-counter 4 : S5 4  S6 15
# Cycle Finished at 240 in com2
# Setting min-density to 0.8
# side1-counter 3 : S1 4  S4 21
# side2-counter 4 : S2 27  S6 25
# side3-counter 4 : S3 7  S7 8
# side4-counter 4 : S5 8  S8 26
# Cycle Finished at 16 in com3
# Setting min-density to 1.33
# side1-counter 4 : S1 6  S5 4
# side2-counter 4 : S2 5  S7 8
# side3-counter 4 : S3 6  S6 10
# side4-counter 4 : S4 20  S8 20
# Cycle Finished at 32 in com7
# Setting min-density to 1.25
# side1-counter 4 : S1 6  S4 10
# side2-counter 4 : S2 11  S6 9
# side3-counter 4 : S3 8  S7 13
# side4-counter 4 : S5 6  S8 10
# Cycle Finished at 48 in com3
# Setting min-density to 1.5
# side1-counter 4 : S1 6  S2 11
# side2-counter 4 : S3 9  S7 8
# side3-counter 4 : S4 14  S8 17
# side4-counter 4 : S5 7  S6 12
# Cycle Finished at 64 in com2
# Setting min-density to 1.5
# side1-counter 4 : S1 5  S2 11
# side2-counter 4 : S3 9  S7 8
# side3-counter 4 : S4 9  S8 13
# side4-counter 4 : S5 6  S6 10
# Cycle Finished at 80 in com2
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S5 5
# side2-counter 4 : S2 14  S6 9
# side3-counter 4 : S3 6  S4 9
# side4-counter 4 : S7 5  S8 15
# Cycle Finished at 96 in com5
# Setting min-density to 1.25
# side1-counter 4 : S1 5  S2 12
# side2-counter 4 : S3 6  S7 2
# side3-counter 4 : S4 10  S8 12
# side4-counter 4 : S5 5  S6 8
# Cycle Finished at 112 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S5 6
# side2-counter 4 : S2 13  S6 9
# side3-counter 4 : S3 6  S4 12
# side4-counter 4 : S7 6  S8 13
# Cycle Finished at 128 in com5
# Setting min-density to 1.25
# side1-counter 4 : S1 4  S4 9
# side2-counter 4 : S2 12  S6 9
# side3-counter 4 : S3 8  S7 10
# side4-counter 4 : S5 4  S8 11
# Cycle Finished at 144 in com3
# Setting min-density to 1.0
# side1-counter 4 : S1 5  S5 2
# side2-counter 4 : S2 9  S7 9
# side3-counter 4 : S3 8  S6 9
# side4-counter 4 : S4 11  S8 15
# Cycle Finished at 160 in com7
# Setting min-density to 0.8
# side1-counter 4 : S1 5  S2 4
# side2-counter 4 : S3 8  S7 9
# side3-counter 4 : S4 11  S8 10
# side4-counter 4 : S5 13  S6 11
# Cycle Finished at 176 in com2
# Setting min-density to 1.25
# side1-counter 4 : S1 6  S5 0
# side2-counter 4 : S2 9  S6 11
# side3-counter 4 : S3 6  S4 8
# side4-counter 4 : S7 1  S8 9
# Cycle Finished at 192 in com5
# Setting min-density to 0.8
# side1-counter 4 : S1 7  S5 6
# side2-counter 4 : S2 14  S6 11
# side3-counter 4 : S3 8  S7 11
# side4-counter 4 : S4 12  S8 9
# Cycle Finished at 208 in com6
# Setting min-density to 1.5
# side1-counter 4 : S1 3  S5 6
# side2-counter 4 : S2 9  S6 9
# side3-counter 4 : S3 9  S7 6
# side4-counter 4 : S4 12  S8 10
# Cycle Finished at 224 in com6
# Setting min-density to 0.8
# side1-counter 4 : S1 6  S5 4
# side2-counter 4 : S2 10  S7 8
# side3-counter 4 : S3 9  S6 8
# side4-counter 4 : S4 12  S8 9
# Cycle Finished at 240 in com7
# Setting min-density to 1.0
# side1-counter 3 : S1 0  S2 18
# side2-counter 4 : S3 8  S7 6
# side3-counter 4 : S4 23  S8 22
# side4-counter 4 : S5 1  S6 26
# Cycle Finished at 16 in com2
# Setting min-density to 0.8
# side1-counter 4 : S1 2  S4 7
# side2-counter 4 : S2 13  S7 6
# side3-counter 4 : S3 8  S6 10
# side4-counter 4 : S5 1  S8 19
# Cycle Finished at 32 in com4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Train the model for a specific number of timesteps
# ----> 2 model.learn(total_timesteps=10000)
#       4 # Save the model
#       5 model.save(model_save_path)
#
# File ~/Desktop/Workings/Jupyter/dsenv/lib/python3.12/site-packages/stable_baselines3/a2c/a2c.py:201, in A2C.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     192 def learn(
#     193     self: SelfA2C,
#     194     total_timesteps: int,
#    (...)
#     199     progress_bar: bool = False,
#     200 ) -> SelfA2C:
# --> 201     return super().learn(
#     202         total_timesteps=total_timesteps,
#     203         callback=callback,
#     204         log_interval=log_interval,
#     205         tb_log_name=tb_log_name,
#     206         reset_num_timesteps=reset_num_timesteps,
#     207         progress_bar=progress_bar,
#     208     )
#
# File ~/Desktop/Workings/Jupyter/dsenv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:300, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     297 assert self.env is not None
#     299 while self.num_timesteps < total_timesteps:
# --> 300     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     302     if not continue_training:
#     303         break
#
# File ~/Desktop/Workings/Jupyter/dsenv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:195, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     190     else:
#     191         # Otherwise, clip the actions to avoid out of bound error
#     192         # as we are sampling from an unbounded Gaussian distribution
#     193         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 195 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     197 self.num_timesteps += env.num_envs
#     199 # Give access to local variables
#
# File ~/Desktop/Workings/Jupyter/dsenv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/Desktop/Workings/Jupyter/dsenv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/Desktop/Workings/Jupyter/dsenv/lib/python3.12/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# Cell In[2], line 66, in TrafficSimulation.step(self, action)
#      63 self.netlogo.command(f'set side4 {green_light_durations[3]}')
#      65 # Run the NetLogo model until the cycle completes
# ---> 66 self.netlogo.command('go-cycle')  # Use the go-cycle method to run a full cycle
#      68 # Get the new observation (densities)
#      69 observation = self.get_current_densities()
#
# File ~/Desktop/Workings/Jupyter/dsenv/lib/python3.12/site-packages/pynetlogo/core.py:272, in NetLogoLink.command(self, netlogo_command)
#     257 """Execute the supplied command in NetLogo
#     258
#     259 Parameters
#    (...)
#     268
#     269 """
#     271 try:
# --> 272     self.link.command(netlogo_command)
#     273 except jpype.JException as ex:
#     274     print(ex.stacktrace())
#
# KeyboardInterrupt:

# %%
from stable_baselines3 import A2C

# %%
model2 = A2C("MultiInputPolicy", env, verbose=1, tensorboard_log=log_path)
# Train the model
model2.learn(total_timesteps=20000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to TestTraining/Logs/A2C_1
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 80.4     |
# | time/                 |          |
# |    fps                | 341      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -13.7    |
# |    explained_variance | 0.0354   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 33.5     |
# |    value_loss         | 7.78     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 87.4     |
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -13.3    |
# |    explained_variance | -0.00639 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 31.9     |
# |    value_loss         | 7.25     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 91.1     |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 300      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -13.5    |
# |    explained_variance | 0.00503  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 32.3     |
# |    value_loss         | 6.53     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 92.5     |
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 400      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -13.3    |
# |    explained_variance | -0.00192 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 31.7     |
# |    value_loss         | 5.83     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 93.7     |
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 500      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -12.3    |
# |    explained_variance | 0.00171  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 26.9     |
# |    value_loss         | 5.19     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 100       |
# |    ep_rew_mean        | 94.7      |
# | time/                 |           |
# |    fps                | 376       |
# |    iterations         | 600       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -12.1     |
# |    explained_variance | -0.000947 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 20.3      |
# |    value_loss         | 4.61      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 95.5     |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 700      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -11      |
# |    explained_variance | 0.000598 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 19.2     |
# |    value_loss         | 4.05     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 96       |
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 800      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -11.1    |
# |    explained_variance | 0.000708 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 17.5     |
# |    value_loss         | 3.53     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 96.4     |
# | time/                 |          |
# |    fps                | 355      |
# |    iterations         | 900      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -11      |
# |    explained_variance | -7.5e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 17.1     |
# |    value_loss         | 3.05     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 96.7     |
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 1000     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -10.3    |
# |    explained_variance | 0.000232 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 10.9     |
# |    value_loss         | 2.6      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 97       |
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 1100     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -10.3    |
# |    explained_variance | 6.2e-05  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 12.7     |
# |    value_loss         | 2.19     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 97.2     |
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 1200     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -11.7    |
# |    explained_variance | 8.11e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 14       |
# |    value_loss         | 1.82     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 100       |
# |    ep_rew_mean        | 97.4      |
# | time/                 |           |
# |    fps                | 363       |
# |    iterations         | 1300      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -10.3     |
# |    explained_variance | -3.39e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 12        |
# |    value_loss         | 1.48      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 97.6     |
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 1400     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -9.01    |
# |    explained_variance | 8.54e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 8.79     |
# |    value_loss         | 1.17     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 97.8     |
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 1500     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -10      |
# |    explained_variance | 0.000139 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 7.25     |
# |    value_loss         | 0.902    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 97.9     |
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 1600     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -9.75    |
# |    explained_variance | 0.000131 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 6.22     |
# |    value_loss         | 0.667    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 98       |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 1700     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -9.52    |
# |    explained_variance | 4.52e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 4.71     |
# |    value_loss         | 0.471    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 100       |
# |    ep_rew_mean        | 98.1      |
# | time/                 |           |
# |    fps                | 355       |
# |    iterations         | 1800      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -8.28     |
# |    explained_variance | -0.000156 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 5.3       |
# |    value_loss         | 0.31      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 98.2     |
# | time/                 |          |
# |    fps                | 355      |
# |    iterations         | 1900     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -5.9     |
# |    explained_variance | 0.000528 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 2.75     |
# |    value_loss         | 0.175    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 98.2     |
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 2000     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -5.95    |
# |    explained_variance | 0.000108 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 1.51     |
# |    value_loss         | 0.0811   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 99.2     |
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 2100     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -6.45    |
# |    explained_variance | 3.24e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.583    |
# |    value_loss         | 0.0233   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 100       |
# |    ep_rew_mean        | 99.5      |
# | time/                 |           |
# |    fps                | 354       |
# |    iterations         | 2200      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -5.58     |
# |    explained_variance | -0.000356 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | 0.102     |
# |    value_loss         | 0.000799  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 100       |
# |    ep_rew_mean        | 99.6      |
# | time/                 |           |
# |    fps                | 354       |
# |    iterations         | 2300      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -5.83     |
# |    explained_variance | -6.79e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | 0.0111    |
# |    value_loss         | 7.67e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 99.7     |
# | time/                 |          |
# |    fps                | 355      |
# |    iterations         | 2400     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -5.81    |
# |    explained_variance | 0.0096   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.00789  |
# |    value_loss         | 2.22e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 99.8     |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 2500     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -5.71    |
# |    explained_variance | -0.00979 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.00421  |
# |    value_loss         | 1.1e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 99.8     |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 2600     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -6.44    |
# |    explained_variance | -0.088   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.00465  |
# |    value_loss         | 1.06e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 99.8     |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 2700     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -7.15    |
# |    explained_variance | 0.122    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.00447  |
# |    value_loss         | 7.72e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 99.8     |
# | time/                 |          |
# |    fps                | 355      |
# |    iterations         | 2800     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -7.86    |
# |    explained_variance | 0.489    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.00575  |
# |    value_loss         | 8.92e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 99.9     |
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 2900     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -7.86    |
# |    explained_variance | 0.0191   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.00637  |
# |    value_loss         | 6.43e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 99.9     |
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 3000     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -7.38    |
# |    explained_variance | -0.0155  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.00517  |
# |    value_loss         | 5.11e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 99.9     |
# | time/                 |          |
# |    fps                | 355      |
# |    iterations         | 3100     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -7.55    |
# |    explained_variance | 0.0511   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.00473  |
# |    value_loss         | 4.67e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 99.9     |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 3200     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -7.29    |
# |    explained_variance | 0.0858   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.00416  |
# |    value_loss         | 4.82e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 99.9     |
# | time/                 |          |
# |    fps                | 355      |
# |    iterations         | 3300     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -6.73    |
# |    explained_variance | -0.00757 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.00519  |
# |    value_loss         | 5.18e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 99.9     |
# | time/                 |          |
# |    fps                | 355      |
# |    iterations         | 3400     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -7.63    |
# |    explained_variance | 0.0223   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.00555  |
# |    value_loss         | 7.41e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 100       |
# |    ep_rew_mean        | 99.9      |
# | time/                 |           |
# |    fps                | 356       |
# |    iterations         | 3500      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -6.89     |
# |    explained_variance | -0.000405 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | 0.00411   |
# |    value_loss         | 4.87e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 99.9     |
# | time/                 |          |
# |    fps                | 357      |
# |    iterations         | 3600     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -7.15    |
# |    explained_variance | -0.0654  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.00472  |
# |    value_loss         | 5.45e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 99.9     |
# | time/                 |          |
# |    fps                | 358      |
# |    iterations         | 3700     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -7.32    |
# |    explained_variance | -0.109   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.00569  |
# |    value_loss         | 5.06e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 100      |
# | time/                 |          |
# |    fps                | 358      |
# |    iterations         | 3800     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -7.39    |
# |    explained_variance | 0.14     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.00612  |
# |    value_loss         | 6.17e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 100      |
# | time/                 |          |
# |    fps                | 358      |
# |    iterations         | 3900     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -7.68    |
# |    explained_variance | 2.35e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.00488  |
# |    value_loss         | 5.58e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 100      |
# | time/                 |          |
# |    fps                | 359      |
# |    iterations         | 4000     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -7.67    |
# |    explained_variance | -0.021   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.00567  |
# |    value_loss         | 5.17e-07 |
# ------------------------------------

# %% [markdown]
# ## Evaluate Policy

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Define the path where your PPO model is saved
model_save_path = os.path.join('Training', 'PPO_Traffic_Model')

# Initialize the environment
env = TrafficSimulation()

# Load the saved model
model = PPO.load(model_save_path, env=env)

evaluate_policy(model, env, n_eval_episodes=10)
# Out:
# C:\Users\LENOVO\AppData\Roaming\Python\Python312\site-packages\stable_baselines3\common\save_util.py:167: UserWarning: Could not deserialize object clip_range. Consider using `custom_objects` argument to replace this object.
# Exception: Can't get attribute '_function_setstate' on <module 'cloudpickle.cloudpickle' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\cloudpickle\\cloudpickle.py'>
#   warnings.warn(
# C:\Users\LENOVO\AppData\Roaming\Python\Python312\site-packages\stable_baselines3\common\save_util.py:167: UserWarning: Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: Can't get attribute '_function_setstate' on <module 'cloudpickle.cloudpickle' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\cloudpickle\\cloudpickle.py'>
#   warnings.warn(
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\LENOVO\AppData\Roaming\Python\Python312\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Setting min-density to 1.5
# Setting min-density to 1.6
# Setting min-density to 1.8
# Setting min-density to 1.4
# Setting min-density to 1.4
# Setting min-density to 1.6
# Setting min-density to 1.6
# Setting min-density to 1.4
# Setting min-density to 1.4
# Setting min-density to 1.2
# Setting min-density to 1.4
# Setting min-density to 1.4
# Setting min-density to 1.4
# Setting min-density to 1.2
# Setting min-density to 1.6
# Setting min-density to 0.8
# Setting min-density to 1.0
# Setting min-density to 1.0
# Setting min-density to 0.8
# Setting min-density to 1.4
# Setting min-density to 1.2
# Setting min-density to 1.2
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 1.0
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 1.75
# Setting min-density to 1.2
# Setting min-density to 1.0
# Setting min-density to 1.6
# Setting min-density to 1.2
# Setting min-density to 1.4
# Setting min-density to 1.2
# Setting min-density to 1.4
# Setting min-density to 1.4
# Setting min-density to 1.4
# Setting min-density to 1.2
# Setting min-density to 1.4
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 1.25
# Setting min-density to 0.8
# Setting min-density to 1.4
# Setting min-density to 1.6
# Setting min-density to 1.4
# Setting min-density to 2.0
# Setting min-density to 1.4
# Setting min-density to 1.6
# Setting min-density to 1.6
# Setting min-density to 1.8
# Setting min-density to 1.0
# Setting min-density to 1.8
# Setting min-density to 1.8
# Setting min-density to 1.6
# Setting min-density to 1.6
# Setting min-density to 0.8
# Setting min-density to 1.2
# Setting min-density to 0.8
# Setting min-density to 1.2
# Setting min-density to 0.8
# Setting min-density to 1.0
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 1.0
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 1.6
# Setting min-density to 1.2
# Setting min-density to 1.6
# Setting min-density to 1.2
# Setting min-density to 1.6
# Setting min-density to 1.2
# Setting min-density to 1.4
# Setting min-density to 1.2
# Setting min-density to 1.2
# Setting min-density to 1.4
# Setting min-density to 1.4
# Setting min-density to 1.4
# Setting min-density to 1.4
# Setting min-density to 1.6
# Setting min-density to 1.2
# Setting min-density to 1.6
# Setting min-density to 0.8
# Setting min-density to 1.2
# Setting min-density to 0.8
# Setting min-density to 1.2
# Setting min-density to 1.0
# Setting min-density to 1.4
# Setting min-density to 0.8
# Setting min-density to 1.0
# Setting min-density to 1.2
# Setting min-density to 1.4
# Setting min-density to 0.8
# Setting min-density to 1.2
# Setting min-density to 0.8
# Setting min-density to 1.2
# Setting min-density to 1.75
# Setting min-density to 1.2
# Setting min-density to 1.2
# Setting min-density to 1.2
# Setting min-density to 1.6
# Setting min-density to 1.4
# Setting min-density to 0.8
# Setting min-density to 1.6
# Setting min-density to 1.2
# Setting min-density to 1.6
# Setting min-density to 0.8
# Setting min-density to 1.2
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 1.6
# Setting min-density to 1.0
# Setting min-density to 1.6
# Setting min-density to 1.2
# Setting min-density to 1.4
# Setting min-density to 1.2
# Setting min-density to 1.2
# Setting min-density to 1.2
# Setting min-density to 1.4
# Setting min-density to 1.0
# Setting min-density to 0.8
# Setting min-density to 1.0
# Setting min-density to 1.4
# Setting min-density to 1.2
# Setting min-density to 0.8
# Setting min-density to 1.0
# Setting min-density to 1.0
# Setting min-density to 1.2
# Setting min-density to 1.2
# Setting min-density to 1.4
# Setting min-density to 1.0
# Setting min-density to 1.0
# Setting min-density to 0.8
# Setting min-density to 1.6
# Setting min-density to 1.2
# Setting min-density to 1.2
# Setting min-density to 0.8
# Setting min-density to 0.8
# Setting min-density to 1.0
# Setting min-density to 1.2
# (0.8, 2.2715633383201097)

# %%
obs, info = env.reset()

# %%
# Predict the action using only the observation
action, _states = model.predict(obs)

print(action)
# Out:
# [ 4 14 22  0 32]
